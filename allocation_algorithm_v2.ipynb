# %% [markdown]
# # Setup

# %%
import pandas as pd
# from collections import defaultdict
# from operator import itemgetter
import numpy as np
# import re
# from fuzzywuzzy import process, fuzz

# Display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
dsd = "DSD2324_overview (2).xlsx"
preferences = "Teaching Preferences Questionnaire_S1_2023-24_raw.xlsx"
contract = "ta_contract_v1.xlsx"
bs_weights = "course_demand_extended_bs_weights.xlsx"
term = "S1"

# %% [markdown]
# # DEMAND - practical lessons

# %%
dsd_df = pd.read_excel(dsd)
# Out:
# d:\Programs\anaconda\envs\adpro2023\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dsd_df.head()
# Out:
#    ORDER TERM CYCLE  COURSE CODE                     COURSE NAME LANGUAGE  \
# 0      1   S1   BSC         1104  Seminário de Economia Europeia       EN
# 1      2   S1   BSC         1104  Seminário de Economia Europeia       EN
# 2      3   S1   BSC         1104  Seminário de Economia Europeia       EN
# 3      4   S2   BSC         1104  Seminário de Economia Europeia       EN
# 4      5   S2   BSC         1104  Seminário de Economia Europeia       EN
#
#    CLASS  SLOTS  WEIGHT PROGRAM  FORMAT INSTITUTIONAL ID FACULTY ID  \
# 0  T301A     35   1.000     NaN  NORMAL            16699        146
# 1  T302A     35   1.000     NaN  NORMAL            16699        146
# 2  T303A     35   1.000     NaN  NORMAL            16699        146
# 3  T301A     40   1.000     NaN  NORMAL            16699        146
# 4  T302A     40   1.000     NaN  NORMAL            16699        146
#
#   FACULTY NAME       FACULTY EMAIL  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 0  João Amador  jamador@novasbe.pt          NaN          NaN          NaN
# 1  João Amador  jamador@novasbe.pt          NaN          NaN          NaN
# 2  João Amador  jamador@novasbe.pt          NaN          NaN          NaN
# 3  João Amador  jamador@novasbe.pt          NaN          NaN          NaN
# 4  João Amador  jamador@novasbe.pt          NaN          NaN          NaN
#
#    Unnamed: 18 LAST UPDATED AT
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN

# %%
dsd_df["course"] = dsd_df["COURSE CODE"].astype(str) + " || " + dsd_df["COURSE NAME"].astype(str) + " || " + dsd_df["TERM"].astype(str) + " || " + dsd_df["LANGUAGE"].astype(str)

if term == "S1":
    selected_terms = ["S1", "T1", "T2"]
    dsd_df = dsd_df[dsd_df['TERM'].isin(selected_terms)]
else:
    selected_terms = ["S2", "T3", "T4"]
    dsd_df = dsd_df[dsd_df['TERM'].isin(selected_terms)]

# %%
agg_functions = {
    'CLASS': 'count',
    'SLOTS': np.sum
    # 'COURSE NAME': 'first'  # Add 'COURSE NAME' to the aggregation functions
}

output_1 = dsd_df.groupby(['COURSE NAME', 'TERM', 'COURSE CODE', 'LANGUAGE']).agg(agg_functions).reset_index()
output_1 = output_1.rename(columns={'CLASS': 'Nº CLASSES', 'SLOTS': 'Nº STUDENTS'})


output_1.head()
# Out:
#                               COURSE NAME TERM  COURSE CODE LANGUAGE  \
# 0                  Advanced Data Analysis   S1         2597       EN
# 1           Advanced Financial Management   S1         2581       EN
# 2                      Advanced Marketing   S1         2430       EN
# 3  Advanced Maths and Stats for Economics   T1         4508       EN
# 4                        Advanced Methods   S1       270107       EN
#
#    Nº CLASSES  Nº STUDENTS
# 0           2          140
# 1           4          360
# 2           8          480
# 3           1          999
# 4           1           15

# %%
dsd_df.TERM.value_counts(dropna=False)
# Out:
# S1    291
# T2    131
# T1    128
# Name: TERM, dtype: int64

# %%
course_demand = dsd_df.groupby(['course']).agg(agg_functions).reset_index()
course_demand = course_demand.rename(columns={'CLASS': 'number_classes', 'SLOTS': 'number_students'})

course_demand.head()
# Out:
#                                               course  number_classes  \
# 0        107789 || Innovation for Impact || T2 || EN               2
# 1  1104 || Seminário de Economia Europeia || S1 |...               3
# 2    1108 || Economia do Desenvolvimento || S1 || EN               2
# 3            1112 || Economia Industrial || S1 || EN               3
# 4              1113 || Economia Global I || S1 || EN               2
#
#    number_students
# 0              140
# 1              105
# 2               70
# 3              126
# 4               84

# %% [markdown]
# # SUPPLY - TA hours (current contract)

# %%
contract = pd.read_excel(contract)

contract["TA"] = contract["TA"].str.lower()

# Zero contracts
zero_contracts = contract[contract['contract'] == 0]["TA"].unique()
contract = contract[contract['contract'] != 0]

# %%
zero_contracts
# Out:
# array(['silvia.guerra@novasbe.pt', 'joana.matos@novasbe.pt'], dtype=object)

# %%
# Check for duplicates
contract[contract.duplicated()].TA.count()
# Out:
# 0

# %%
contract_emails = contract.TA.unique()

# %%
contract.head()
# Out:
#                           TA  contract
# 0    abrao.kulaif@novasbe.pt     0.500
# 1  afonso.ribeiro@novasbe.pt     0.500
# 2  afonso.serrano@novasbe.pt     0.250
# 3   afonso.castro@novasbe.pt     0.500
# 4   afonso.duarte@novasbe.pt     0.175

# %% [markdown]
# # SUPPLY - TA preferences

# %% [markdown]
# ## A. Preferences

# %%
# Read the Excel file with the second row as the header
preferences_df = pd.read_excel(preferences, header=1)

# Sort the DataFrame by "End Date" column in descending order
preferences_df = preferences_df.sort_values(by='End Date', ascending=False)

# Rename the column to "TA"
preferences_df.rename(columns={'Please write your E-mail @novasbe.pt': 'TA'}, inplace=True)

# Convert the values in the "TA" column to lowercase
preferences_df['TA'] = preferences_df['TA'].str.lower()

# Remove TAs with zero_contracts
preferences_df = preferences_df[~preferences_df["TA"].isin(zero_contracts)]

# Create a mask to identify duplicates in the "TA" column
duplicates_mask = preferences_df.duplicated(subset='TA', keep=False)
preferences_duplicates = preferences_df[duplicates_mask]
preferences_duplicates = preferences_duplicates.sort_values(by='End Date', ascending=False)

preferences_duplicates_last = preferences_duplicates.drop_duplicates(subset='TA', keep='first').copy()

# Create a mask to check if columns 31:81 or 83:347 have values
value_mask = preferences_duplicates.iloc[:, 31:81].notnull().any(axis=1) | preferences_duplicates.iloc[:, 83:347].notnull().any(axis=1)
preferences_duplicates_values = preferences_duplicates[value_mask]
preferences_duplicates_values = preferences_duplicates_values.drop_duplicates(subset='TA', keep='first').copy()

# Drop duplicates based on the "TA" column
preferences_df = preferences_df[~duplicates_mask]

# Drop duplicates based on the "Full Name" column while keeping the row with the most recent "End Date" (ex. Franziska wrong)
preferences_df = preferences_df.drop_duplicates(subset='Full Name', keep='first')

# Create a new DataFrame with columns from preferences_duplicates_last
preferences_df_final = preferences_duplicates_last.copy()

# Get the relevant columns from preferences_duplicates_values
preference_columns = preferences_duplicates_values.columns[31:81].tolist() + preferences_duplicates_values.columns[83:347].tolist()

# Update the values in preferences_df_final using values from preferences_duplicates_values for preference_columns
preferences_df_final.set_index('TA', inplace=True, drop=False)
preferences_duplicates_values.set_index('TA', inplace=True, drop=False)
preferences_df_final.loc[preferences_duplicates_values.index, preference_columns] = preferences_duplicates_values[preference_columns].values

# Concatenate the remaining columns from preferences_df to preferences_df_final
preferences_df_final = pd.concat([preferences_df_final, preferences_df])

# Sort the final DataFrame by "End Date" column in descending order
preferences_df_final.sort_values(by='End Date', ascending=False, inplace=True)

# Reset the index of the final DataFrame
preferences_df_final.reset_index(drop=True, inplace=True)

# Drop duplicates based on the "Full Name" column while keeping the row with the most recent "End Date" (ex. Franziska wrong )
preferences_df_final.drop_duplicates(subset='Full Name', keep='first', inplace=True)

# Create a mapping of original column names to new column names (course ID as integer)
mapping = {}
# course_full_codes = []

for column_name in preference_columns:
    # Extract the course ID number from the column name
    # course_id = column_name.split(' || ')[0].split(' - ')[3] + " || " + column_name.split(' || ')[1] + ' || ' +  column_name.split(' || ')[2].split(' - ')[0]
    course_id = column_name.split(' || ')[0].split(' - ')[3] + " || "  + column_name.split(' || ')[0].split(' - ')[4]+ " || " + column_name.split(' || ')[1] + ' || ' +  column_name.split(' || ')[2].split(' - ')[0]
    
    # Extract full course ID for matching later
    # course_full_codes.append(column_name.split(' || ')[0].split(' - ')[3] + " || "  + column_name.split(' || ')[0].split(' - ')[4]+ " || " + column_name.split(' || ')[1] + ' || ' +  column_name.split(' || ')[2].split(' - ')[0])
    
    # Map the original column name to the course ID
    mapping[column_name] = course_id

# Remove duplicates
# course_full_codes = list(set(course_full_codes))

# Rename the columns using the mapping
preferences_df_final.rename(columns=mapping, inplace=True)

# Drop columns with list of courses (redundant) [30, 81, and 82]
preferences_df_final.drop(columns=preferences_df_final.iloc[:,[30, 81, 82]], inplace=True)

# OUTPUT #2
# Filter the DataFrame for rows where "Do you intend to continue your collaboration with Nova SBE next semester as Teaching Assistant?" 
# (column 20) is not equal to "No"
ta_exits = preferences_df_final[preferences_df_final.iloc[:, 19] == "No"].iloc[:, [17, 18, 20]]
ta_exits = ta_exits.rename(columns={ta_exits.columns[-1]: "Comments"}).sort_values("Full Name")

# ta_exits.to_excel("ta_exits_v1.xlsx", index=False)
ta_exits_list = ta_exits.TA.unique()

preferences_df_final = preferences_df_final[preferences_df_final.iloc[:, 19] != "No"]
# Out:
#                                   Full Name                             TA  \
# 166                    Afonso Ferro Serrano      afonso.serrano@novasbe.pt
# 132                        Alessandro Capra    alessandro.capra@novasbe.pt
# 67   Alexandra Filipa Luz Cardoso Lourenço   alexandra.lourenco@novasbe.pt
# 29                        André Pinto Bessa         andre.bessa@novasbe.pt
# 77     Carlos Tomasio Fernandes Lopes Neves        carlos.neves@novasbe.pt
#
#                                               Comments
# 166                        Leaving the country in July
# 132  I have been accepted for a PhD program abroad ...
# 67   Eu estou grávida e o meu bebé irá nascer em No...
# 29   I will be abroad during the next academic year...
# 77   I will be living abroad Portugal in the 2nd se...

# %%
print(f"Number of TAs who are leaving: {len(ta_exits_list)}")
# Out:
# Number of TAs who are leaving: 17

# %%
# Check that can use the email as key/ ID
preferences_df_final["TA"].isnull().sum()
# Out:
# 0

# %%
# Check there are no duplicates names
preferences_df_final[preferences_df_final["Full Name"].duplicated()]["Response ID"].count()
# Out:
# 0

# %%
# Check there are no duplicates answers
preferences_df_final[preferences_df_final["TA"].duplicated()]["Response ID"].count()
# Out:
# 0

# %%
responded_number = preferences_df_final.shape[0] 
print(f"Number of TAs willing to continue who responded: {responded_number}")
display(preferences_df_final[["TA", "Full Name"]].head())
# Out:
# Number of TAs willing to continue who responded: 175
#                               TA                                   Full Name
# 0  beatriz.f.ferreira@novasbe.pt                     Beatriz Frazão Ferreira
# 1        sara.b.lopes@novasbe.pt  Sara de Louxembourg Henriques Borges Lopes
# 3        marcio.silva@novasbe.pt                       Marcio Nunes da Silva
# 4        ana.lourenco@novasbe.pt                  Ana Filipa Duarte Lourenço
# 5     fabian.wassmann@novasbe.pt                             Fabian Wassmann

# %%
# OUTPUT #N
preferences_df_final[~preferences_df_final.iloc[:,-1].isna()].iloc[:, [17, 18, -1]]
# Out:
#                                             Full Name  \
# 0                             Beatriz Frazão Ferreira
# 3                               Marcio Nunes da Silva
# 8                           Andre Daniel Vinhas Nunes
# 9                                  Franziska Hittmair
# 18                       Valter Miguel Sobral Nóbrega
# 21      Afonso Maria Jardim Gonçalves Teixeira Duarte
# 24   Gonçalo Maria de Abreu Peixoto Cordeiro de Sousa
# 31                         Rafael de Almeida Sequeira
# 34                       Maria José Rodrigues Aniceto
# 35                         Afonso Saraiva Câmara Leme
# 36                Carlos Alberto Antunes Reis Marques
# 40                  Francisco Gonçalves Matias Mendes
# 41                      João Maria Loureiro Rodrigues
# 43                                    Milton Figueira
# 50                      João Mário de Almeida Caetano
# 51                                  Joana Sousa Leite
# 53                  Afonso Teixeira da Silva Quintela
# 57                                  Galina Vysotskaya
# 59            Madalena Lopes Pereira Marques da Silva
# 61                                      Diogo Marques
# 65                  João Miguel Falcão Pinto da Silva
# 68                      João Maria Santos Matos Alves
# 72      Amélia Rita de Oliveira Vinhas Nunes Monteiro
# 76                         Francisco França Rodrigues
# 79                   Pedro Miguel Carreira dos Santos
# 80                         Nuno Miguel Camilo Ribeiro
# 86                                     Lucas Franieck
# 89                       Ana Claudia Mariano Oliveira
# 91                                Alessandro Gambetti
# 93        Marlon Eduardo dos Santos Martins Francisco
# 95                          João Pedro Ramos Ferreira
# 101                          Teresa Duarte Graça Luiz
# 107                   Matilde Filipa Dos Santos Alves
# 109                                  Stefano Granicni
# 111                                   Mariana Videira
# 112                 Henrique Domingos da Silva Santos
# 116       João Nuno Rebelo da Silva Monjardim Quelhas
# 117                            Eduardo Hidalgo Garcia
# 126                                     Mehdi Lehlali
# 133                      Ruben Gonçalo Godinho Bento
# 138                  claudia de jesus letras vaqueiro
# 139                    Diogo Augusto Coutinho Pereira
# 141                                    Lourenco Leite
# 142              Luís de Andrade Guerra Leal de Faria
# 145                                        Radek Oros
# 146                João Miguel Gomes da Silva Firmino
# 150                            Teresa Moana Mannebach
# 151                                        Iqra Hamid
# 160                              Tomás Alves Ambrósio
# 161                       MARIA INES GONCALVES CHARRO
# 162                               Anastasiia Smirnova
# 163         Isabel Henriques de Brito Cabral Burguete
# 165                       Alice Isabel Manilhas Nunes
# 169                       Filipa Maria Marques Albano
# 172                                     Mariana Nobre
# 175              Carolina Pereira Lima Tomás Lourenço
# 176           Daniel Alexandre Lucas Mugeiro da Silva
# 177                        Ana Rita Duarte Tapadinhas
# 180                          Francisco Leonardo Ramos
# 182                     Diogo Manuel Ferreira de Lima
# 186                           Ricardo Coelho da Silva
# 187                                      Sam Applebee
# 189                                 Yulia Vachevskikh
#
#                                      TA  \
# 0         beatriz.f.ferreira@novasbe.pt
# 3               marcio.silva@novasbe.pt
# 8                andre.nunes@novasbe.pt
# 9         hittmair.franziska@novasbe.pt
# 18            valter.nobrega@novasbe.pt
# 21             afonso.duarte@novasbe.pt
# 24             goncalo.sousa@novasbe.pt
# 31           rafael.sequeira@novasbe.pt
# 34             maria.aniceto@novasbe.pt
# 35               afonso.leme@novasbe.pt
# 36            carlos.marques@novasbe.pt
# 40        francisco.g.mendes@novasbe.pt
# 41   joao.loureiro.rodrigues@novasbe.pt
# 43           milton.figueira@novasbe.pt
# 50              joao.caetano@novasbe.pt
# 51               joana.leite@novasbe.pt
# 53           afonso.quintela@novasbe.pt
# 57         galina.vysotskaya@novasbe.pt
# 59            madalena.silva@novasbe.pt
# 61             diogo.marques@novasbe.pt
# 65                joao.silva@novasbe.pt
# 68                joao.alves@novasbe.pt
# 72         amelia.n.monteiro@novasbe.pt
# 76     francisco.f.rodrigues@novasbe.pt
# 79            pedro.m.santos@novasbe.pt
# 80              nuno.ribeiro@novasbe.pt
# 86            lucas.franieck@novasbe.pt
# 89      ana.claudia.oliveira@novasbe.pt
# 91       gambetti.alessandro@novasbe.pt
# 93        marlon.e.francisco@novasbe.pt
# 95             joao.ferreira@novasbe.pt
# 101             teresa.graca@novasbe.pt
# 107            matilde.alves@novasbe.pt
# 109         stefano.grancini@novasbe.pt
# 111        mariana.m.videira@novasbe.pt
# 112        henrique.d.santos@novasbe.pt
# 116             joao.quelhas@novasbe.pt
# 117           eduardo.garcia@novasbe.pt
# 126            mehdi.lehlali@novasbe.pt
# 133              ruben.bento@novasbe.pt
# 138         claudia.vaqueiro@novasbe.pt
# 139          diogo.a.pereira@novasbe.pt
# 141           lourenco.leite@novasbe.pt
# 142               luis.faria@novasbe.pt
# 145               radek.oros@novasbe.pt
# 146             joao.firmino@novasbe.pt
# 150         teresa.mannebach@novasbe.pt
# 151               iqra.hamid@novasbe.pt
# 160         tomas.a.ambrosio@novasbe.pt
# 161             maria.charro@novasbe.pt
# 162      anastasiia.smirnova@novasbe.pt
# 163          isabel.burguete@novasbe.pt
# 165              alice.nunes@novasbe.pt
# 169            filipa.albano@novasbe.pt
# 172            mariana.nobre@novasbe.pt
# 175        carolina.lourenco@novasbe.pt
# 176             daniel.silva@novasbe.pt
# 177           ana.tapadinhas@novasbe.pt
# 180        francisco.l.ramos@novasbe.pt
# 182               diogo.lima@novasbe.pt
# 186          ricardo.c.silva@novasbe.pt
# 187             sam.applebee@novasbe.pt
# 189        yulia.vachevskikh@novasbe.pt
#
#                  Please write below your observations:
# 0    Only for the course of Business Strategy and P...
# 3    I can only handle one course per semester, sin...
# 8    "Economics of education" and "Competition Poli...
# 9                 Global Strategic Management for CEMS
# 18                                 Wiseflow preference
# 21   I would like to be assistant also in Risk Mana...
# 24   I would like to continue to work with Prof Ema...
# 31   If I am allocated to Investments (full course)...
# 34   I would like to keep grading financial managem...
# 35   First option is Economics of Education (shows ...
# 36   I have chosen the courses I have worked on bef...
# 40   Ideally, I would prefer to have classes always...
# 41   As minhas preferências passam naturalmente por...
# 43   O programa de Financial Modeling mudou radical...
# 50   Next semester I will start working at Deloitte...
# 51   I am also interested in other related Masters ...
# 53   Didn't choose any Bachelors course because I a...
# 57   I would really love to teach Development Econo...
# 59   Já tinha submetido o forms, mas pedi para alte...
# 61   Apesar de ter dito que pretendo reduzir a minh...
# 65   No caso de Principles of microeconomics prefer...
# 68   In the past years i have been a TA of the cour...
# 72                                 Only master courses
# 76   My grading options are for a last resort scena...
# 79   Possible ranking would be: energy, environment...
# 80   I am more interested in marketing courses. i a...
# 86   I have worked with Professor Antonio Marinho T...
# 89   Due to my current professional situation outsi...
# 91   IMPORTANT: I am welcome to be a TA next semest...
# 93         Strong preference for Econometrics' classes
# 95   My strong preference would be to remain an Ind...
# 101  Work Projects for the Master in Impact Entrepr...
# 107  I would like to teach my 3rd semester of Manag...
# 109  I would like to keep Intermediate Macroeconomi...
# 111  For the next semester I would prefer to lectur...
# 112  Classes must be concentrated in 1 single day. ...
# 116  No ano 22/23, tive 3 turmas de Macro e fiz gra...
# 117  I have been Teaching Introduction to Programmi...
# 126  Same as last two years, corporate finance at t...
# 133  As in this semester I would like to keep my 50...
# 138  According to prior semester experience I need ...
# 139  I really need grading with no regular class sc...
# 141                  Entrepreneurship with Prof. Nadim
# 142  If it would be possible to reduce my workload ...
# 145  Would like to request to remain as TA/Grader o...
# 146  Disponível para fazer 10 vigilâncias em qualqu...
# 150                Entrepreneurship as always, PLEASE!
# 151  Preference for courses for which exams take pl...
# 160  I might be available to be the TA of the BSc's...
# 161  I will continue to live in the US in the next ...
# 162  You don't provide following courses in a lists...
# 163                    Equipa vencedora não se muda :)
# 165  I am not able to teach bachelor courses as I a...
# 169  Only available to teach statistics II (2434) o...
# 172  As of now, I have been grader of Financial Man...
# 175  Unfortunately, I could only be available at 8a...
# 176  My main objective is to have 4 classes, they c...
# 177  Although my preferred area for Masters courses...
# 180  Para além da cadeira de Auditoria, gostaria ta...
# 182  If I have 2 classes, I would like for them to ...
# 186  I would strongly like to be a TA for Corporate...
# 187  The drag and drop system does not function on ...
# 189  If there are any courses with Utku Serhatli or...

# %%
# OUTPUT #N
preferences_df_final[~preferences_df_final["TA"].isin(contract_emails)][["TA", "Full Name"]]
# Out:
#                          TA     Full Name
# 63            dd@novasbe.pt          dddd
# 85   pedrobrinca@novasbe.pt  Pedro Brinca
# 115          xxx@novasbe.pt           xxx
# 120           aa@novasbe.pt           aaa
# 140         test@novasbe.pt          test

# %%
# Get the course columns
course_columns = preferences_df_final.columns[30:-1]

# Create a new DataFrame for the adapted format
adapted_df = pd.DataFrame(columns=["TA", "course", "preference", "preference_type"])

# Define the translation mapping for column 22 values
translation_mapping = {
    "Masters' Courses": 2,
    "Bachelors' Courses": 0,
    "Indifferent": 1,
    pd.NaT: 1  # Assuming NaN values should also be considered "Indifferent"
}

# Iterate over the course columns
for course in course_columns:
    # Check if the course has already been processed
    if course in adapted_df["course"].unique():
        continue

    # Get the duplicate columns for the current course
    duplicate_columns = [col for col in course_columns if col != course and col.endswith(course)]

    # Combine the duplicate columns into a single column
    combined_column = preferences_df_final[[course] + duplicate_columns].ffill(axis=1).iloc[:, -1]

    # Filter the DataFrame for non-null values in the combined column
    non_null_mask = combined_column.notnull()
    non_null_df = preferences_df_final[non_null_mask]

    # Get the teacher names and their corresponding preference rankings for the current course
    teacher_names = non_null_df["TA"]
    preference_rankings = combined_column[non_null_mask]

    # Get the corresponding preference types based on the translation mapping
    preference_types = non_null_df.iloc[:, 22].map(translation_mapping)

    # Create a DataFrame for the current course, preference rankings, and preference types
    course_df = pd.DataFrame({"TA": teacher_names, "course": [course] * len(teacher_names),
                              "preference": preference_rankings, "preference_type": preference_types})

    # Concatenate course_df with adapted_df
    adapted_df = pd.concat([adapted_df, course_df], ignore_index=True)
    
    # Create the 'masters_course' column based on the condition
    adapted_df['masters_course'] = adapted_df['course'].apply(lambda x: 0 if x.split(' ')[0].startswith('1') else 1)

    # Convert "preference" column to integers
    adapted_df['preference'] = adapted_df['preference'].astype(np.int8)

    # Remove preferences above 5
    adapted_df = adapted_df[adapted_df['preference']<=5]

# %%
# Check there are no preferences above 5 and below 1
print(adapted_df['preference'].min())
print(adapted_df['preference'].max())
# Out:
# 1
# 5

# %%
completed_preferences = adapted_df["TA"].unique()
completed_preferences_number = len(completed_preferences)
print(f"Number of TAs with completed preferences: {completed_preferences_number}")
# display(completed_preferences)
# Out:
# Number of TAs with completed preferences: 162

# %%
# OUTPUT #6
adapted_df.iloc[:,:-1].head()
# Out:
#                               TA  \
# 0       pedro.freitas@novasbe.pt
# 1  marlon.e.francisco@novasbe.pt
# 2        luis.pereira@novasbe.pt
# 3    stefano.grancini@novasbe.pt
# 4        joao.quelhas@novasbe.pt
#
#                                               course  preference  \
# 0  1104 || Seminar in European Economics || S1 || EN           1
# 1  1104 || Seminar in European Economics || S1 || EN           5
# 2  1104 || Seminar in European Economics || S1 || EN           5
# 3  1104 || Seminar in European Economics || S1 || EN           3
# 4  1104 || Seminar in European Economics || S1 || EN           5
#
#   preference_type
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0

# %%
adapted_df[adapted_df["TA"]=="bernardo.costa@novasbe.pt"]
# Out:
#                             TA  \
# 178  bernardo.costa@novasbe.pt
# 191  bernardo.costa@novasbe.pt
# 200  bernardo.costa@novasbe.pt
# 207  bernardo.costa@novasbe.pt
# 517  bernardo.costa@novasbe.pt
# 579  bernardo.costa@novasbe.pt
# 587  bernardo.costa@novasbe.pt
# 636  bernardo.costa@novasbe.pt
#
#                                                 course  preference  \
# 178  1312 || Data Analysis and Probability || S1 || EN           3
# 191  1313 || Statistics for Economics and Managemen...           2
# 200                   1314 || Econometrics || S1 || EN           4
# 207    1318 || Introduction to Programming || S1 || EN           1
# 517   2477 || Introduction to Programming  || S1 || EN           2
# 579         2597 || Advanced Data Analysis || S1 || EN           1
# 587  2609 || Data Visualization for Business Analyt...           4
# 636  2659 || Data Curation for Business Analytics |...           3
#
#     preference_type  masters_course
# 178               1               0
# 191               1               0
# 200               1               0
# 207               1               0
# 517               1               1
# 579               1               1
# 587               1               1
# 636               1               1

# %% [markdown]
# ## B. New contract (preferences)

# %%
contact_list = contract[(~contract.TA.isin(completed_preferences)) & (~contract.TA.isin(ta_exits_list))]
print(contact_list.shape[0])
display(contact_list)
contact_list.to_excel("ta_contact_list_v1.xlsx", index=False)
# Out:
# 34
#                                 TA  contract
# 1        afonso.ribeiro@novasbe.pt     0.500
# 3         afonso.castro@novasbe.pt     0.500
# 20            ana.silva@novasbe.pt     0.200
# 24           andre.tome@novasbe.pt     0.100
# 32      beatriz.marques@novasbe.pt     0.250
# 33        beatriz.bento@novasbe.pt     0.125
# 42    catarina.m.grosso@novasbe.pt     0.900
# 47      claudia.castico@novasbe.pt     0.375
# 54    daniele.gamberoni@novasbe.pt     0.200
# 56       diogo.v.rebelo@novasbe.pt     0.400
# 70   hittmair.franziska@novasbe.pt     0.250
# 80         ines.caetano@novasbe.pt     0.200
# 84        jessica.lomba@novasbe.pt     1.000
# 92         joao.firmino@novasbe.pt     0.100
# 94       joao.m.delgado@novasbe.pt     0.500
# 96      joao.p.baptista@novasbe.pt     0.250
# 97           joao.fanha@novasbe.pt     0.500
# 102      joaquim.f.goes@novasbe.pt     0.375
# 111        lorian.abazi@novasbe.pt     0.250
# 117         luis.simoes@novasbe.pt     0.350
# 125        marco.mendes@novasbe.pt     0.150
# 133         joana.barba@novasbe.pt     0.500
# 142     marli.fernandes@novasbe.pt     0.125
# 147    mateus.rodrigues@novasbe.pt     0.400
# 149    matilde.g.gracio@novasbe.pt     0.250
# 151     miguel.oliveira@novasbe.pt     0.500
# 152      miguel.conduto@novasbe.pt     0.500
# 159           nuno.reis@novasbe.pt     0.250
# 165      patricia.silva@novasbe.pt     0.500
# 178       ricardo.silva@novasbe.pt     0.250
# 183         robert.hill@novasbe.pt     0.500
# 187        sam.applebee@novasbe.pt     0.250
# 196       susana.santos@novasbe.pt     0.250
# 204           tomas.vaz@novasbe.pt     0.250

# %%
def round_to_closest(value):
    if pd.isnull(value):
        return np.nan
    else:
        # rounded_value = round(value * 8) / 8  # Round to the nearest multiple of 0.125
        capped_value = min(value, 0.5)  # Cap the value at 0.5
        capped_value = max(value, 0.1)  # Cap the value at 0.1
        return capped_value

# Clean the "load_requested" column
def clean_percentage(value):
    if pd.isnull(value):
        return value
    elif isinstance(value, str):
        # Check if the value contains only text characters
        if value.isalpha():
            return np.nan

        # Extract numeric values from string
        numeric_value = ''.join(filter(str.isdigit, value))

        if numeric_value == '':
            return np.nan

        if numeric_value == '100':
            return 100

        if len(numeric_value) >= 2:
            integer_part = numeric_value[:2]
            decimal_part = numeric_value[2:]
            return float(integer_part + '.' + decimal_part)

        return np.nan

    elif isinstance(value, (int, float)):
        return float(value) / 100

    return value

def decrease_contract_level(value):
    return value - 0.125


mapping = {
    "I want to increase the contract percentage/workload in the next semester (please specify the desired contract percentage level)": 1,
    "I want to keep the same contract percentage/workload as this semester": 0,
    "I want to reduce the contract percentage/workload in the next semester (please specify the desired contract percentage level)": -1,
    pd.NaT: 0
}

mapping_21 = {
    "Yes, I am a PhD student": 0,
    "Yes, I will be a Masters student but not doing any courses, only the Work Project": 0,
    "Yes, I will be a Masters student and I will be doing at least one more course": 1,
    "No": 0,
    pd.NaT: 0
}

mapping_23 = {
    "Yes, I have some other constraints that limit my teaching hours/workload (please specify the reason and the limit)": 1,
    "Yes, I have a FCT scholarship that limits my weekly teaching hours to 4h per week": 1,
    "No": 0,
    pd.NaT: 0
}

################################################################################################################################################

mask = preferences_df_final.iloc[:, 27].notna()
new_contract = preferences_df_final[mask].iloc[:, [18, 21, 23, 27, 28, 29]]

new_contract.columns = ['TA', 'master_student', 'PhD_restrictions', 'change_load', 'new_contract_decreased_load', 'new_contract_increased_load']
new_contract['change_load'] = new_contract['change_load'].map(mapping)
new_contract['master_student'] = new_contract['master_student'].map(mapping_21).fillna(0).astype(int)
new_contract['PhD_restrictions'] = new_contract['PhD_restrictions'].map(mapping_23).fillna(0).astype(int)

# Convert TA column to lowercase
new_contract['TA'] = new_contract['TA'].str.lower()

new_contract['new_contract_decreased_load'] = new_contract['new_contract_decreased_load'].apply(clean_percentage) / 100
new_contract['new_contract_increased_load'] = new_contract['new_contract_increased_load'].apply(clean_percentage) / 100

# Merge "new_contract_decreased_load" and "new_contract_increased_load" into "load_requested"
new_contract['load_requested'] = new_contract[['new_contract_decreased_load', 'new_contract_increased_load']].mean(axis=1)
new_contract['load_requested'] = new_contract['load_requested'].apply(round_to_closest)

# Drop "new_contract_decreased_load" and "new_contract_increased_load" columns
new_contract.drop(columns=['new_contract_decreased_load', 'new_contract_increased_load'], inplace=True)

# %%
# OUTPUT #3
new_contract[new_contract.change_load !=0].sort_values("TA")
# Out:
#                                    TA  master_student  PhD_restrictions  \
# 21           afonso.duarte@novasbe.pt               0                 0
# 53         afonso.quintela@novasbe.pt               0                 0
# 162    anastasiia.smirnova@novasbe.pt               0                 0
# 8              andre.nunes@novasbe.pt               0                 0
# 118         antonio.santos@novasbe.pt               0                 1
# 138       claudia.vaqueiro@novasbe.pt               0                 0
# 83    constanca.b.roquette@novasbe.pt               0                 0
# 176           daniel.silva@novasbe.pt               0                 0
# 17          daniela.afonso@novasbe.pt               0                 0
# 182             diogo.lima@novasbe.pt               0                 0
# 61           diogo.marques@novasbe.pt               0                 0
# 117         eduardo.garcia@novasbe.pt               0                 0
# 5          fabian.wassmann@novasbe.pt               0                 1
# 179         fernanda.rates@novasbe.pt               0                 0
# 104           filipe.lopes@novasbe.pt               0                 0
# 103      frederico.toulson@novasbe.pt               0                 0
# 112      henrique.d.santos@novasbe.pt               0                 0
# 147             hugo.sousa@novasbe.pt               0                 0
# 173  isabel.silva.carvalho@novasbe.pt               0                 0
# 68              joao.alves@novasbe.pt               0                 0
# 50            joao.caetano@novasbe.pt               0                 0
# 164              joao.gama@novasbe.pt               0                 0
# 190              joao.pato@novasbe.pt               0                 1
# 116           joao.quelhas@novasbe.pt               0                 0
# 97             jose.ferrao@novasbe.pt               0                 0
# 156          laman.orujova@novasbe.pt               0                 0
# 191              lara.pico@novasbe.pt               0                 1
# 142             luis.faria@novasbe.pt               0                 0
# 92          mafalda.afonso@novasbe.pt               0                 0
# 3             marcio.silva@novasbe.pt               0                 1
# 122            maria.vidal@novasbe.pt               0                 0
# 96       mariana.m.marques@novasbe.pt               0                 0
# 25            miguel.bello@novasbe.pt               0                 0
# 155           miguel.matos@novasbe.pt               0                 0
# 80            nuno.ribeiro@novasbe.pt               0                 0
# 144        pamela.pacciani@novasbe.pt               0                 0
# 136          paulo.marques@novasbe.pt               0                 0
# 131           pedro.castro@novasbe.pt               0                 0
# 79          pedro.m.santos@novasbe.pt               0                 1
# 81        renato.goncalves@novasbe.pt               0                 0
# 105            rita.santos@novasbe.pt               0                 0
# 102         rodrigo.duarte@novasbe.pt               0                 0
# 56             rui.boavida@novasbe.pt               0                 0
# 128            tiago.troco@novasbe.pt               0                 0
# 160       tomas.a.ambrosio@novasbe.pt               0                 0
# 184        tomas.rodrigues@novasbe.pt               0                 0
# 189      yulia.vachevskikh@novasbe.pt               0                 1
#
#      change_load  load_requested
# 21             1           0.500
# 53             1             NaN
# 162            1           0.500
# 8              1           0.500
# 118           -1           0.250
# 138           -1           0.100
# 83             1           0.375
# 176            1           0.500
# 17            -1           0.250
# 182            1           0.250
# 61            -1           0.253
# 117            1           1.000
# 5             -1           0.125
# 179            1           0.500
# 104           -1           0.250
# 103            1           0.500
# 112            1           0.375
# 147            1           0.500
# 173            1             NaN
# 68             1           0.500
# 50             1           0.500
# 164           -1           0.250
# 190           -1           0.250
# 116            1           0.500
# 97             1           0.751
# 156           -1           0.350
# 191           -1           0.250
# 142           -1           0.150
# 92             1           0.500
# 3              1             NaN
# 122            1           0.500
# 96             1           0.354
# 25             1           0.300
# 155            1           1.000
# 80             1           0.352
# 144            1           0.500
# 136            1           1.000
# 131           -1           0.125
# 79             1           0.500
# 81            -1           0.100
# 105            1           0.500
# 102            1           0.500
# 56             1           0.500
# 128            1           0.250
# 160           -1             NaN
# 184           -1           0.200
# 189            1           1.000

# %%
# Check new_contract_load is formatted correctly
# new_contract.load_requested.value_counts()

# %%
number_TAS = len(new_contract[new_contract.change_load.isin([1,-1])])
print(f"Number of TAs who want to change their contract: {number_TAS}")
# Out:
# Number of TAs who want to change their contract: 47

# %%
all_contracts = contract.merge(new_contract, how="left", on="TA")

# Filter rows where change_load is not equal to 0
filtered_contracts = all_contracts[all_contracts['change_load'] != 0].copy()

# Decrease contract to load_requested for rows where change_load is -1
filtered_contracts.loc[filtered_contracts['change_load'] == -1, 'new_contract'] = filtered_contracts['load_requested']
filtered_contracts.loc[(filtered_contracts['change_load'] == -1) & (filtered_contracts['load_requested'].isnull()), 'new_contract'] = filtered_contracts.apply(lambda row: decrease_contract_level(row['contract']), axis=1)

# # Increase contract for no restrictions
# filtered_contracts.loc[(filtered_contracts['change_load'] == 1) & (filtered_contracts['restrictions'] == 0), 'new_contract'] = filtered_contracts['load_requested']
# filtered_contracts.loc[(filtered_contracts['change_load'] == 1) & (filtered_contracts['restrictions'] == 0) & (filtered_contracts['load_requested'].isnull()), 'new_contract'] = np.minimum(filtered_contracts['contract'] * 2, 0.5)

# Apply conditions for updating new_contract based on change_load and restrictions
# filtered_contracts.loc[(filtered_contracts['change_load'] == 1) & (filtered_contracts['restrictions'] == 1), 'new_contract'] = filtered_contracts['contract']
# filtered_contracts.loc[(filtered_contracts['change_load'] == 1) & (filtered_contracts['restrictions'] == 2), 'new_contract'] = np.maximum(filtered_contracts['contract'], 0.25)

# Fill NaN values with the original contract value
filtered_contracts['new_contract'].fillna(filtered_contracts['contract'], inplace=True)

# Create a new column "new_contract" in the original DataFrame with NaN values
all_contracts['new_contract'] = np.nan

# Update the "new_contract" column in the original DataFrame with the filtered values
all_contracts.update(filtered_contracts[['new_contract']])
all_contracts['new_contract'].fillna(all_contracts['contract'], inplace=True)

# Round the "new_contract" values to the closest contract level (0.125, 0.25, 0.375, 0.5)
# all_contracts['new_contract'] = all_contracts['new_contract'].apply(round_to_closest)

# Drop emails which currently do not have a contract (ex. pedro.brinca)
all_contracts = all_contracts[all_contracts.contract.notna()]

# %%
# Check there are no TAs wihout current contract
all_contracts[all_contracts.contract.isnull()].TA.to_list()
# Out:
# []

# %%
all_contracts = all_contracts[["TA", "new_contract", "master_student"]]

# %% [markdown]
# ## C. Merge SUPPLY and DEMAND

# %%
ta_preferences = adapted_df.merge(all_contracts, how="left", on="TA", indicator=True)
ta_preferences.head()
# Out:
#                               TA  \
# 0       pedro.freitas@novasbe.pt
# 1  marlon.e.francisco@novasbe.pt
# 2        luis.pereira@novasbe.pt
# 3    stefano.grancini@novasbe.pt
# 4        joao.quelhas@novasbe.pt
#
#                                               course  preference  \
# 0  1104 || Seminar in European Economics || S1 || EN           1
# 1  1104 || Seminar in European Economics || S1 || EN           5
# 2  1104 || Seminar in European Economics || S1 || EN           5
# 3  1104 || Seminar in European Economics || S1 || EN           3
# 4  1104 || Seminar in European Economics || S1 || EN           5
#
#   preference_type  masters_course  new_contract  master_student _merge
# 0               0               0         0.375           0.000   both
# 1               1               0         0.500           0.000   both
# 2               0               0         0.500           1.000   both
# 3               1               0         0.250           0.000   both
# 4               0               0         0.375           0.000   both

# %%
# Check for non-matching TAs
non_matching_values = ta_preferences[ta_preferences['_merge'] != 'both']
ta_preferences.drop(columns=["_merge"], inplace=True)
display(non_matching_values)
# Out:
# Empty DataFrame
# Columns: [TA, course, preference, preference_type, masters_course, new_contract, master_student, _merge]
# Index: []

# %%
market = ta_preferences.merge(course_demand, how="left", on="course", indicator=True)

# market['number_classes'] = pd.to_numeric(market['number_classes'], errors='coerce').astype(pd.Int64Dtype())
# market['number_students'] = pd.to_numeric(market['number_students'], errors='coerce').astype(pd.Int64Dtype())

# %%
non_matching_values = market[market['_merge'] != 'both']
market.drop(columns=["_merge"], inplace=True)

non_matching_courses = non_matching_values[["course"]].drop_duplicates()
non_matching_courses = non_matching_courses.copy()
non_matching_courses[["course_code", "course_name", "period", "language"]] = non_matching_courses["course"].str.split(" \|\| ", expand=True)

course_demand_extended = course_demand.copy()
course_demand_extended[["course_code", "course_name", "period", "language"]] = course_demand["course"].str.split(" \|\| ", expand=True)
course_demand_extended = course_demand_extended[["course", "course_code", "course_name", "period", "language"]]

# %%
# Initialize an empty DataFrame to store the concatenated results
concatenated_matches = pd.DataFrame()

# Merge on 'course_code', 'period', and 'language'
merged_courses = pd.merge(non_matching_courses, course_demand_extended, on=["course_code", "period", "language"], how="left", suffixes=("", "_new"))
still_unmatched = merged_courses[merged_courses["course_new"].isna()][["course", "course_name", "course_code", "period", "language"]]
concatenated_matches = pd.concat([concatenated_matches, merged_courses[~merged_courses["course_new"].isna()][["course", "course_new"]]])

# Merge on 'course_name', 'period', and 'language'
merged_courses = pd.merge(still_unmatched, course_demand_extended, on=["course_name", "period", "language"], how="left", suffixes=("", "_new"))
still_unmatched = merged_courses[merged_courses["course_new"].isna()][["course", "course_name", "course_code", "period", "language"]]
concatenated_matches = pd.concat([concatenated_matches, merged_courses[~merged_courses["course_new"].isna()][["course", "course_new"]]])

# Merge on 'course_code' and 'period'
merged_courses = pd.merge(still_unmatched, course_demand_extended, on=["course_code", "period"], how="left", suffixes=("", "_new"))
still_unmatched = merged_courses[merged_courses["course_new"].isna()][["course", "course_name", "course_code", "period", "language"]]
concatenated_matches = pd.concat([concatenated_matches, merged_courses[~merged_courses["course_new"].isna()][["course", "course_new"]]])

# # [DANGER! Might include courses from different semester] Merge on 'course_code' and 'language' 
# merged_courses = pd.merge(still_unmatched, course_demand_extended, on=["course_code", "language"], how="left", suffixes=("", "_new"))
# still_unmatched = merged_courses[merged_courses["course_new"].isna()][["course", "course_name", "course_code", "period", "language"]]
# concatenated_matches = pd.concat([concatenated_matches, merged_courses[~merged_courses["course_new"].isna()][["course", "course_new"]]])

# Merge concatenated_matches on the market DataFrame to add the "course_new" column
market = pd.merge(market, concatenated_matches[["course", "course_new"]], on=["course"], how="left")
market["course_new"].fillna(market["course"], inplace=True)
market.rename(columns={"course": "course_old"}, inplace=True)
market.drop(columns=["course_old"], inplace=True)
market.rename(columns={"course_new": "course"}, inplace=True)

# Merge market and course_demand on "course" column
merged_market = pd.merge(market, course_demand[["course", "number_classes", "number_students"]], on="course", how="left", suffixes=("", "_demand"))

# Fill NaN values in number_classes and number_students columns
merged_market["number_classes"].fillna(merged_market["number_classes_demand"], inplace=True)
merged_market["number_students"].fillna(merged_market["number_students_demand"], inplace=True)

# Drop the unnecessary columns
merged_market.drop(columns=["number_classes_demand", "number_students_demand"], inplace=True)

# %%
# OUTPUT #4
# Display the updated merged_market DataFrame
no_matches_final = merged_market[(merged_market.number_classes.isna()) | (merged_market.number_students.isna())][["course"]]
no_matches_final = no_matches_final.drop_duplicates()
display(no_matches_final)

# Drop these courses
merged_market.dropna(subset=["number_classes", "number_students"], inplace=True)
# Out:
#                                                 course
# 243         2134 || Economics of Education || T1 || EN
# 348         2260 || Nova Students Portfolio || A || EN
# 376  2329 || Consumer and Managerial Decision Makin...
# 381              2330 || Consumer Behavior || T2 || EN
# 488  2452 || Business Strategy and Practice || T2 |...
# 581  2604 || Brand Management for Hospitality || T2...
# 590        2621 || Algorithmic Governance  || T1 || EN
# 605  2642 || Principles of Shopper Marketing || T2 ...
# 609              2645 || Tourism Marketing || S1 || EN
# 629                  2653 || Impact Makers || S1 || EN
# 631  2655 || Introduction to Hospitality  & Tourism...
# 652        2742 || Policy Analysis Exercise || A || EN
# 680     2877 || Strategy in Global Markets || S1 || EN
# 685     2957 || Applied Business analytics || S1 || EN
# 686        2958 || Applied Global Strategy || S1 || EN

# %% [markdown]
# ## D. Compute capacity

# %%
# Create the "semester" column based on the condition
merged_market['semester'] = merged_market['course'].apply(lambda x: 1 if x.split(' || ')[2].startswith('S') else 0)
merged_market['ms_capacity'] = merged_market['new_contract'] * 36

# Define a function to apply the conditions
def calculate_weight(row):
    if row['semester'] == 1:
        return (row['number_students'] * 2.33) / 16
    else:
        return (row['number_students'] * 1.25) / 16

# Apply the function to create the 'ms_weight' column
merged_market['ms_weight'] = merged_market.apply(calculate_weight, axis=1)

# Set 'ms_capacity' to NaN when 'masters_course' is 0
merged_market.loc[merged_market['masters_course'] == 0, 'ms_capacity'] = np.nan
merged_market.loc[merged_market['masters_course'] == 0, 'ms_weight'] = np.nan

merged_market.head()
# Out:
#                               TA  preference preference_type  masters_course  \
# 0       pedro.freitas@novasbe.pt           1               0               0
# 1  marlon.e.francisco@novasbe.pt           5               1               0
# 2        luis.pereira@novasbe.pt           5               0               0
# 3    stefano.grancini@novasbe.pt           3               1               0
# 4        joao.quelhas@novasbe.pt           5               0               0
#
#    new_contract  master_student  number_classes  number_students  \
# 0         0.375           0.000           3.000          105.000
# 1         0.500           0.000           3.000          105.000
# 2         0.500           1.000           3.000          105.000
# 3         0.250           0.000           3.000          105.000
# 4         0.375           0.000           3.000          105.000
#
#                                               course  semester  ms_capacity  \
# 0  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 1  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 2  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 3  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 4  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
#
#    ms_weight
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# ### Get file course list to manually input the weights

# %%
course_demand_extended['masters_course'] = course_demand_extended['course'].apply(lambda x: 0 if x.split(' ')[0].startswith('1') else 1)
course_demand_extended_bs = course_demand_extended[course_demand_extended.masters_course==0]
course_demand_extended_bs = course_demand_extended_bs.drop(columns=["masters_course"])
course_demand_extended_bs["weight"] = ""
course_demand_extended_bs.to_excel("course_demand_extended_bs.xlsx", index=False)

# %% [markdown]
# ### Read the manually inputed weights

# %%
bs_weights_df = pd.read_excel(bs_weights)[["course", "weight"]]
bs_weights_df["weight"] = bs_weights_df["weight"] * 0.125
bs_weights_df.weight.value_counts(dropna=False)
# Out:
# 0.125    90
# 0.333     8
# 0.167     3
# 0.250     1
# Name: weight, dtype: int64

# %%
final_market = pd.merge(merged_market, bs_weights_df, on=["course"], how="left", suffixes=("", "_new"), indicator=True)
final_market.head()
# Out:
#                               TA  preference preference_type  masters_course  \
# 0       pedro.freitas@novasbe.pt           1               0               0
# 1  marlon.e.francisco@novasbe.pt           5               1               0
# 2        luis.pereira@novasbe.pt           5               0               0
# 3    stefano.grancini@novasbe.pt           3               1               0
# 4        joao.quelhas@novasbe.pt           5               0               0
#
#    new_contract  master_student  number_classes  number_students  \
# 0         0.375           0.000           3.000          105.000
# 1         0.500           0.000           3.000          105.000
# 2         0.500           1.000           3.000          105.000
# 3         0.250           0.000           3.000          105.000
# 4         0.375           0.000           3.000          105.000
#
#                                               course  semester  ms_capacity  \
# 0  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 1  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 2  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 3  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 4  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
#
#    ms_weight  weight _merge
# 0        NaN   0.125   both
# 1        NaN   0.125   both
# 2        NaN   0.125   both
# 3        NaN   0.125   both
# 4        NaN   0.125   both

# %%
# Check there are no BS courses without weight
final_market[(final_market["_merge"] != "both") & (final_market.masters_course==0)]
# Out:
#                             TA  preference preference_type  masters_course  \
# 202    marcio.silva@novasbe.pt           3               0               0
# 203     paulo.rocha@novasbe.pt           2               0               0
# 204     jose.ferrao@novasbe.pt           2               0               0
# 205  eduardo.garcia@novasbe.pt           1               0               0
# 206   paulo.marques@novasbe.pt           1               1               0
# 207  bernardo.costa@novasbe.pt           1               1               0
# 208    miguel.matos@novasbe.pt           1               1               0
#
#      new_contract  master_student  number_classes  number_students  \
# 202         0.050           0.000           6.000          270.000
# 203         0.500           0.000           6.000          270.000
# 204         0.500           0.000           6.000          270.000
# 205         0.500           0.000           6.000          270.000
# 206         0.330           0.000           6.000          270.000
# 207         0.500           0.000           6.000          270.000
# 208         0.500           0.000           6.000          270.000
#
#                               course  semester  ms_capacity  ms_weight  \
# 202  1318 || Programação || S1 || EN         1          NaN        NaN
# 203  1318 || Programação || S1 || EN         1          NaN        NaN
# 204  1318 || Programação || S1 || EN         1          NaN        NaN
# 205  1318 || Programação || S1 || EN         1          NaN        NaN
# 206  1318 || Programação || S1 || EN         1          NaN        NaN
# 207  1318 || Programação || S1 || EN         1          NaN        NaN
# 208  1318 || Programação || S1 || EN         1          NaN        NaN
#
#      weight     _merge
# 202     NaN  left_only
# 203     NaN  left_only
# 204     NaN  left_only
# 205     NaN  left_only
# 206     NaN  left_only
# 207     NaN  left_only
# 208     NaN  left_only

# %%
final_market.rename(columns={"weight": "bs_weight", "new_contract": "bs_capacity"}, inplace=True)
final_market.drop(columns="_merge", inplace=True)

final_market["bs_weight"] = final_market["bs_weight"] * final_market["number_classes"]

final_market.loc[final_market['masters_course'] == 1, 'bs_capacity'] = np.nan
final_market.loc[final_market['masters_course'] == 1, 'bs_weight'] = np.nan

# %%
final_market.head()
# Out:
#                               TA  preference preference_type  masters_course  \
# 0       pedro.freitas@novasbe.pt           1               0               0
# 1  marlon.e.francisco@novasbe.pt           5               1               0
# 2        luis.pereira@novasbe.pt           5               0               0
# 3    stefano.grancini@novasbe.pt           3               1               0
# 4        joao.quelhas@novasbe.pt           5               0               0
#
#    bs_capacity  master_student  number_classes  number_students  \
# 0        0.375           0.000           3.000          105.000
# 1        0.500           0.000           3.000          105.000
# 2        0.500           1.000           3.000          105.000
# 3        0.250           0.000           3.000          105.000
# 4        0.375           0.000           3.000          105.000
#
#                                               course  semester  ms_capacity  \
# 0  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 1  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 2  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 3  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
# 4  1104 || Seminário de Economia Europeia || S1 |...         1          NaN
#
#    ms_weight  bs_weight
# 0        NaN      0.375
# 1        NaN      0.375
# 2        NaN      0.375
# 3        NaN      0.375
# 4        NaN      0.375

# %%
final_market[final_market.TA=="bernardo.costa@novasbe.pt"]
# Out:
#                             TA  preference preference_type  masters_course  \
# 178  bernardo.costa@novasbe.pt           3               1               0
# 191  bernardo.costa@novasbe.pt           2               1               0
# 200  bernardo.costa@novasbe.pt           4               1               0
# 207  bernardo.costa@novasbe.pt           1               1               0
# 493  bernardo.costa@novasbe.pt           2               1               1
# 555  bernardo.costa@novasbe.pt           1               1               1
# 561  bernardo.costa@novasbe.pt           4               1               1
# 601  bernardo.costa@novasbe.pt           3               1               1
#
#      bs_capacity  master_student  number_classes  number_students  \
# 178        0.500           0.000           2.000           90.000
# 191        0.500           0.000           8.000          340.000
# 200        0.500           0.000           2.000           76.000
# 207        0.500           0.000           6.000          270.000
# 493          NaN           0.000           4.000          320.000
# 555          NaN           0.000           2.000          140.000
# 561          NaN           0.000           2.000          140.000
# 601          NaN           0.000           2.000          130.000
#
#                                                 course  semester  ms_capacity  \
# 178  1312 || Análise de Dados e Probabilidade || S1...         1          NaN
# 191  1313 || Estatística para Economia e Gestão || ...         1          NaN
# 200                    1314 || Econometria || S1 || EN         1          NaN
# 207                    1318 || Programação || S1 || EN         1          NaN
# 493   2477 || Introduction to Programming  || S1 || EN         1       18.000
# 555         2597 || Advanced Data Analysis || S1 || EN         1       18.000
# 561  2609 || Data Visualization for Business Analyt...         0       18.000
# 601  2659 || Data Curation for Business Analytics |...         0       18.000
#
#      ms_weight  bs_weight
# 178        NaN      0.667
# 191        NaN      1.000
# 200        NaN      0.250
# 207        NaN        NaN
# 493     46.600        NaN
# 555     20.387        NaN
# 561     10.938        NaN
# 601     10.156        NaN

# %%
tas = final_market.TA.unique()

# Find elements missing in array1 compared to array2
missing_elements = np.setdiff1d(completed_preferences, tas)

# OUTPUT #N: TAs affected by unmatched courses
print(missing_elements)
# Out:
# ['beatriz.f.ferreira@novasbe.pt' 'mariana.pires@novasbe.pt']

# %% [markdown]
# # Matching algorithm

# %%
# # Function to allocate courses based on capacity and workload
# def allocate_courses(df, capacity, weight_col, preference_col, max_exceed):
#     allocated_courses = []

#     for _, row in df.iterrows():
#         ta = row["TA"]
#         course = row["course"]
#         workload = row[weight_col]
#         preference_type = row[preference_col]

#         if pd.isnull(workload):
#             continue

#         allocated = [cap >= workload or (cap < workload and workload - cap <= max_exceed) for cap in capacity]
#         if any(allocated):
#             allocated_courses.append((ta, course))
#             slice_length = len(df.loc[(df["TA"] == ta) & (df[preference_col] == preference_type), weight_col])
#             df.loc[(df["TA"] == ta) & (df[preference_col] == preference_type), weight_col] = np.where(allocated[:slice_length], np.nan, df.loc[(df["TA"] == ta) & (df[preference_col] == preference_type), weight_col].tolist())
#             capacity = [cap - workload if alloc else cap for cap, alloc in zip(capacity, allocated)]

#     return allocated_courses

# # Filter the dataframe based on masters_course column
# masters_courses = final_market[final_market["masters_course"]==1].copy() # adpat to consider preference_type and master_student instead
# bachelors_courses = final_market[final_market["masters_course"]==0].copy()

# # Sort the filtered dataframes based on preference
# masters_prefs = masters_courses.sort_values(by="preference")
# bachelors_prefs = bachelors_courses.sort_values(by="preference")

# # Initialize dictionaries to track capacity and weight per TA
# ta_capacity_map = {}
# ta_weight_map = {}

# # Allocate bachelor's courses
# bachelor_capacity = (bachelors_courses["bs_capacity"] - bachelors_courses["bs_weight"].fillna(0)).tolist()
# bachelor_allocations = allocate_courses(bachelors_prefs, bachelor_capacity, "bs_weight", "preference_type", max_exceed=0)

# # Update capacity and weight dictionaries for bachelor allocations
# for ta, course in bachelor_allocations:
#     index = bachelors_prefs[(bachelors_prefs["TA"] == ta) & (bachelors_prefs["course"] == course)].index[0]
#     ta_capacity_map[ta][index] -= bachelors_prefs.loc[index, "bs_weight"]

# # Allocate master's courses with remaining capacity (allowing up to 3 points exceed)
# master_capacity = (masters_courses["ms_capacity"] - masters_courses["ms_weight"].fillna(0)).tolist()
# master_allocations = allocate_courses(masters_prefs, master_capacity, "ms_weight", "preference_type", max_exceed=3)

# # Update capacity and weight dictionaries for master allocations
# for ta, course in master_allocations:
#     index = masters_prefs[(masters_prefs["TA"] == ta) & (masters_prefs["course"] == course)].index[0]
#     ta_capacity_map[ta][index] -= masters_prefs.loc[index, "ms_weight"]

# # Combine allocations from both types of courses
# allocations = pd.DataFrame(bachelor_allocations + master_allocations, columns=["TA", "course"])

# # Remove duplicates from allocations and include remaining capacities and weights
# allocations = allocations.drop_duplicates()
# allocations = allocations.merge(final_market[["TA", "bs_capacity", "ms_capacity"]], on="TA")
# allocations["bs_weight_remaining"] = allocations["TA"].map(lambda x: sum(ta_weight_map[x][i] for i, alloc in enumerate(bachelor_allocations) if alloc[0] == x))
# allocations["ms_weight_remaining"] = allocations["TA"].map(lambda x: sum(ta_weight_map[x][i] for i, alloc in enumerate(master_allocations) if alloc[0] == x))

# # Sort the final allocation dataframe by TA
# allocations = allocations.sort_values(by=["TA"])

# %%
ms_courses = final_market[(final_market['masters_course'] == 1) & (final_market['master_student'] == 0)]
ms_courses_dict = dict(zip(ms_courses['course'], ms_courses['ms_weight']))
ms_ta_dict = dict(zip(ms_courses['TA'], ms_courses['ms_capacity']))

bs_courses = final_market[final_market['masters_course'] == 0]
bs_courses_dict = dict(zip(bs_courses['course'], bs_courses['bs_weight']))
bs_ta_dict = dict(zip(bs_courses['TA'], bs_courses['bs_capacity']))

# %%
translation_mapping
# Out:
# {"Masters' Courses": 2, "Bachelors' Courses": 0, 'Indifferent': 1, NaT: 1}

# %%
ms_final_preferences = ms_courses[["TA", "preference_type", "preference", "course", "semester"]]
ms_final_preferences = ms_final_preferences.sort_values(by=["course", "preference_type", "preference"], ascending=[True, False, True])

bs_final_preferences = bs_courses[["TA", "preference_type", "preference", "course", "semester"]]
bs_final_preferences = bs_final_preferences.sort_values(by=["course", "preference_type", "preference"], ascending=[True, True, True])

# %%
ms_final_preferences
# Out:
#                                      TA preference_type  preference  \
# 243              andre.nunes@novasbe.pt               2           1
# 245              joana.leite@novasbe.pt               2           1
# 244             afonso.moura@novasbe.pt               2           3
# 247              luis.morais@novasbe.pt               2           4
# 248         stefano.grancini@novasbe.pt               1           1
# 246    francisco.f.rodrigues@novasbe.pt               0           1
# 249             pedro.coelho@novasbe.pt               0           1
# 251             daniel.silva@novasbe.pt               0           1
# 252               diogo.lima@novasbe.pt               0           1
# 250             joao.quelhas@novasbe.pt               0           5
# 253           valter.nobrega@novasbe.pt               2           1
# 254            afonso.duarte@novasbe.pt               2           3
# 255              luis.morais@novasbe.pt               2           5
# 256       marlon.e.francisco@novasbe.pt               1           1
# 258           antonio.santos@novasbe.pt               1           1
# 257         stefano.grancini@novasbe.pt               1           2
# 259        galina.vysotskaya@novasbe.pt               2           1
# 262             maria.charro@novasbe.pt               2           5
# 260         vitor.cavalcante@novasbe.pt               1           1
# 263       frederica.mendonca@novasbe.pt               1           1
# 261       marlon.e.francisco@novasbe.pt               1           2
# 267                joao.pato@novasbe.pt               2           3
# 264              andre.nunes@novasbe.pt               2           5
# 266              ruben.bento@novasbe.pt               1           3
# 265             joao.quelhas@novasbe.pt               0           4
# 270            laman.orujova@novasbe.pt               2           1
# 271                joao.pato@novasbe.pt               2           1
# 269            joao.ferreira@novasbe.pt               0           1
# 268    francisco.f.rodrigues@novasbe.pt               0           2
# 278           priya.krishnan@novasbe.pt               2           1
# 277               iqra.hamid@novasbe.pt               2           2
# 275              luis.morais@novasbe.pt               2           3
# 274        galina.vysotskaya@novasbe.pt               2           4
# 279                joao.pato@novasbe.pt               2           4
# 272          fabian.wassmann@novasbe.pt               2           5
# 273      svitlana.sivitskaya@novasbe.pt               1           3
# 276              ruben.bento@novasbe.pt               1           5
# 284            laman.orujova@novasbe.pt               2           5
# 282               hugo.sousa@novasbe.pt               1           2
# 281             joao.quelhas@novasbe.pt               0           1
# 280             pedro.coelho@novasbe.pt               0           2
# 283          diogo.guerreiro@novasbe.pt               0           2
# 285               diogo.lima@novasbe.pt               0           2
# 288          antonio.cardoso@novasbe.pt               2           1
# 289               joao.costa@novasbe.pt               2           1
# 287            afonso.duarte@novasbe.pt               2           2
# 286             ana.lourenco@novasbe.pt               0           5
# 290              joana.leite@novasbe.pt               2           2
# 291               joao.costa@novasbe.pt               2           3
# 292        francisco.l.ramos@novasbe.pt               2           1
# 294           mariana.coelho@novasbe.pt               2           1
# 293          afonso.quintela@novasbe.pt               2           2
# 296           mariana.coelho@novasbe.pt               2           2
# 295          afonso.quintela@novasbe.pt               2           3
# 297          rafael.sequeira@novasbe.pt               2           2
# 299          afonso.quintela@novasbe.pt               2           1
# 300           joao.c.delgado@novasbe.pt               2           5
# 298             ana.lourenco@novasbe.pt               0           4
# 302        goncalo.s.marques@novasbe.pt               2           1
# 303          bogdana.blidari@novasbe.pt               2           1
# 304          rafael.sequeira@novasbe.pt               2           1
# 307               joao.alves@novasbe.pt               2           1
# 308           joao.c.delgado@novasbe.pt               2           1
# 306       antonio.m.bernardo@novasbe.pt               2           2
# 305             joao.caetano@novasbe.pt               1           4
# 301             ana.lourenco@novasbe.pt               0           3
# 310           miguel.marques@novasbe.pt               2           2
# 311          antonio.cardoso@novasbe.pt               2           5
# 312             joao.caetano@novasbe.pt               1           2
# 309             ana.lourenco@novasbe.pt               0           1
# 313          fabian.wassmann@novasbe.pt               2           1
# 315             afonso.moura@novasbe.pt               2           1
# 314           valter.nobrega@novasbe.pt               2           2
# 318       frederica.mendonca@novasbe.pt               1           4
# 317                joao.gama@novasbe.pt               0           2
# 316             joao.quelhas@novasbe.pt               0           3
# 320               joao.costa@novasbe.pt               2           2
# 321              alice.nunes@novasbe.pt               2           2
# 319       antonio.m.bernardo@novasbe.pt               2           4
# 322           mafalda.afonso@novasbe.pt               2           1
# 324              maria.vidal@novasbe.pt               0           1
# 323             pedro.coelho@novasbe.pt               0           3
# 327           miguel.marques@novasbe.pt               2           1
# 334            mehdi.lehlali@novasbe.pt               2           1
# 336          tomas.rodrigues@novasbe.pt               2           1
# 337          miguel.m.duarte@novasbe.pt               2           1
# 326        goncalo.s.marques@novasbe.pt               2           2
# 332           mafalda.afonso@novasbe.pt               2           2
# 335           joao.c.delgado@novasbe.pt               2           2
# 331       antonio.m.bernardo@novasbe.pt               2           3
# 328          antonio.cardoso@novasbe.pt               2           4
# 330          afonso.quintela@novasbe.pt               2           4
# 329             joao.caetano@novasbe.pt               1           1
# 325             ana.lourenco@novasbe.pt               0           2
# 333              maria.vidal@novasbe.pt               0           2
# 338          rafael.sequeira@novasbe.pt               2           3
# 340            afonso.duarte@novasbe.pt               2           1
# 341              daniel.belo@novasbe.pt               2           1
# 339          fabian.wassmann@novasbe.pt               2           2
# 343             afonso.moura@novasbe.pt               2           2
# 344              daniel.belo@novasbe.pt               2           2
# 342              andre.nunes@novasbe.pt               2           4
# 345            maria.aniceto@novasbe.pt               2           2
# 346          milton.figueira@novasbe.pt               2           2
# 347          antonio.cardoso@novasbe.pt               2           2
# 348           mafalda.afonso@novasbe.pt               2           3
# 350           joao.c.delgado@novasbe.pt               2           3
# 349              maria.vidal@novasbe.pt               0           3
# 351            maria.aniceto@novasbe.pt               2           3
# 352          milton.figueira@novasbe.pt               2           3
# 353          antonio.cardoso@novasbe.pt               2           3
# 354           mafalda.afonso@novasbe.pt               2           4
# 355           joao.c.delgado@novasbe.pt               2           4
# 356           daniela.afonso@novasbe.pt               2           1
# 358             maria.charro@novasbe.pt               2           2
# 359           ines.f.moreira@novasbe.pt               2           2
# 357        galina.vysotskaya@novasbe.pt               2           5
# 362             maria.amorim@novasbe.pt               2           1
# 360        mariana.m.marques@novasbe.pt               2           3
# 363              asgari.omid@novasbe.pt               2           3
# 364              leonor.leao@novasbe.pt               2           4
# 361         goncalo.oliveira@novasbe.pt               1           2
# 367             pedro.castro@novasbe.pt               2           1
# 368           lourenco.leite@novasbe.pt               2           1
# 365         teresa.goncalves@novasbe.pt               1           1
# 366              jose.ferrao@novasbe.pt               0           2
# 370        amelia.n.monteiro@novasbe.pt               2           1
# 371             pedro.castro@novasbe.pt               2           4
# 373                lara.pico@novasbe.pt               1           1
# 372           carolina.ramos@novasbe.pt               1           2
# 369           annsophie.hahn@novasbe.pt               1           4
# 374        amelia.n.monteiro@novasbe.pt               2           2
# 375              tiago.troco@novasbe.pt               2           5
# 376           carolina.ramos@novasbe.pt               1           1
# 377                lara.pico@novasbe.pt               1           2
# 378        mariana.m.marques@novasbe.pt               2           1
# 379         goncalo.oliveira@novasbe.pt               1           4
# 380        mariana.m.marques@novasbe.pt               2           2
# 382            diogo.marques@novasbe.pt           2.000           3
# 384           lucas.franieck@novasbe.pt               1           1
# 383           marta.nogueira@novasbe.pt               1           4
# 385             ana.faustino@novasbe.pt               1           1
# 386           lucas.franieck@novasbe.pt               1           2
# 388  joao.loureiro.rodrigues@novasbe.pt               2           1
# 389         maria.m.carvalho@novasbe.pt               2           3
# 391           ana.tapadinhas@novasbe.pt               2           3
# 393        yulia.vachevskikh@novasbe.pt               2           4
# 387                ana.neves@novasbe.pt               1           3
# 392           fernanda.rates@novasbe.pt               1           3
# 390              ana.marques@novasbe.pt               0           2
# 394           carlos.marques@novasbe.pt               2           3
# 395             ana.faustino@novasbe.pt               1           2
# 396             joao.almeida@novasbe.pt               0           4
# 397             sara.b.lopes@novasbe.pt               2           1
# 398        carolina.lourenco@novasbe.pt               2           1
# 399            maria.aniceto@novasbe.pt               2           1
# 400          milton.figueira@novasbe.pt               2           1
# 403       antonio.m.bernardo@novasbe.pt               2           1
# 404              alice.nunes@novasbe.pt               2           1
# 405            mariana.nobre@novasbe.pt               2           1
# 406          tomas.rodrigues@novasbe.pt               2           2
# 402          afonso.quintela@novasbe.pt               2           5
# 401             joao.caetano@novasbe.pt               1           3
# 407             sara.b.lopes@novasbe.pt               2           2
# 409        amelia.n.monteiro@novasbe.pt               2           3
# 410               iqra.hamid@novasbe.pt               2           3
# 408       antonio.m.bernardo@novasbe.pt               2           5
# 412         maria.m.carvalho@novasbe.pt               2           2
# 414           ines.f.moreira@novasbe.pt               2           3
# 411                ana.neves@novasbe.pt               1           2
# 413                joao.gama@novasbe.pt               0           3
# 416             pedro.castro@novasbe.pt               2           3
# 418              asgari.omid@novasbe.pt               2           4
# 417         mariia.murasheva@novasbe.pt               1           1
# 415         teresa.goncalves@novasbe.pt               1           2
# 420              rita.mendes@novasbe.pt               2           1
# 421             filipe.lopes@novasbe.pt               2           1
# 423              leonor.leao@novasbe.pt               2           2
# 422             maria.amorim@novasbe.pt               2           4
# 419             nuno.ribeiro@novasbe.pt               1           2
# 426            sonia.vilares@novasbe.pt               2           1
# 425            sofia.vilares@novasbe.pt               2           2
# 424             sara.b.lopes@novasbe.pt               2           3
# 431             maria.amorim@novasbe.pt               2           3
# 428        mariana.m.marques@novasbe.pt               2           4
# 430           tania.sequeira@novasbe.pt               2           4
# 432        carolina.lourenco@novasbe.pt               2           4
# 427             nuno.ribeiro@novasbe.pt               1           3
# 429         goncalo.oliveira@novasbe.pt               1           3
# 439              ligia.nunes@novasbe.pt               2           1
# 436                 rita.vaz@novasbe.pt               2           2
# 433          fabian.wassmann@novasbe.pt               2           3
# 434              afonso.leme@novasbe.pt               2           3
# 438            laman.orujova@novasbe.pt               2           3
# 440            filipa.albano@novasbe.pt               2           3
# 435              joana.leite@novasbe.pt               2           5
# 437              paulo.rocha@novasbe.pt               0           5
# 443              ligia.nunes@novasbe.pt               2           2
# 441                 rita.vaz@novasbe.pt               2           3
# 442            laman.orujova@novasbe.pt               2           4
# 444            filipa.albano@novasbe.pt               2           4
# 448              tiago.troco@novasbe.pt               2           1
# 451            filipa.albano@novasbe.pt               2           1
# 450              ligia.nunes@novasbe.pt               2           3
# 445          fabian.wassmann@novasbe.pt               2           4
# 446              afonso.leme@novasbe.pt               2           4
# 449          diogo.a.pereira@novasbe.pt               1           3
# 447        frederico.toulson@novasbe.pt               0           1
# 454            filipa.albano@novasbe.pt               2           2
# 453              ligia.nunes@novasbe.pt               2           4
# 452          diogo.a.pereira@novasbe.pt               1           4
# 461      anastasiia.smirnova@novasbe.pt               2           1
# 457      gambetti.alessandro@novasbe.pt               2           2
# 456         renato.goncalves@novasbe.pt               2           3
# 455              joana.leite@novasbe.pt               2           4
# 460               paulo.ruiz@novasbe.pt               2           4
# 459             diogo.alvito@novasbe.pt               2           5
# 458              jose.ferrao@novasbe.pt               0           4
# 462             sara.b.lopes@novasbe.pt               2           1
# 463         claudia.vaqueiro@novasbe.pt               2           1
# 464            diogo.marques@novasbe.pt               2           2
# 465    isabel.silva.carvalho@novasbe.pt               2           3
# 466           carlos.marques@novasbe.pt               2           4
# 467         tomas.a.ambrosio@novasbe.pt               2           2
# 468            goncalo.sousa@novasbe.pt               2           1
# 470          ricardo.c.silva@novasbe.pt               2           2
# 469           tania.sequeira@novasbe.pt               2           3
# 471             diogo.alvito@novasbe.pt               2           3
# 472              tiago.troco@novasbe.pt               2           4
# 473               iqra.hamid@novasbe.pt               2           5
# 474        amelia.n.monteiro@novasbe.pt               2           5
# 475             pedro.castro@novasbe.pt               2           5
# 477    isabel.silva.carvalho@novasbe.pt               2           5
# 476          diogo.a.pereira@novasbe.pt               1           1
# 478            sofia.vilares@novasbe.pt               2           1
# 479             diogo.alvito@novasbe.pt               2           1
# 480             pedro.castro@novasbe.pt               2           2
# 481         claudia.vaqueiro@novasbe.pt               2           2
# 482      anastasiia.smirnova@novasbe.pt               2           2
# 483          catarina.leitao@novasbe.pt               2           1
# 485          tomas.rodrigues@novasbe.pt               2           5
# 484             ana.faustino@novasbe.pt               1           3
# 486            luis.carvalho@novasbe.pt               2           1
# 495           claudio.vieira@novasbe.pt               2           1
# 496           angelo.s.alves@novasbe.pt               2           1
# 497          guilherme.ramos@novasbe.pt               2           1
# 488           mafalda.afonso@novasbe.pt               2           5
# 491               paulo.ruiz@novasbe.pt               2           5
# 492            paulo.marques@novasbe.pt               1           1
# 494             miguel.matos@novasbe.pt               1           1
# 493           bernardo.costa@novasbe.pt               1           2
# 487              paulo.rocha@novasbe.pt               0           1
# 489              jose.ferrao@novasbe.pt               0           1
# 490        frederico.toulson@novasbe.pt               0           2
# 501           priya.krishnan@novasbe.pt               2           2
# 498           carlos.marques@novasbe.pt               2           5
# 499           miguel.marques@novasbe.pt               2           5
# 500         claudia.vaqueiro@novasbe.pt               2           5
# 502           carlos.marques@novasbe.pt               2           1
# 503          ayodeji.olufemi@novasbe.pt               2           3
# 505           ana.tapadinhas@novasbe.pt               2           5
# 504             nuno.ribeiro@novasbe.pt               1           4
# 506         maria.m.carvalho@novasbe.pt               2           5
# 508             abrao.kulaif@novasbe.pt               1           1
# 509           fernanda.rates@novasbe.pt               1           1
# 507              ana.marques@novasbe.pt               0           1
# 515          ricardo.c.silva@novasbe.pt               2           1
# 514              tiago.troco@novasbe.pt               2           2
# 510           miguel.marques@novasbe.pt               2           4
# 512            diogo.marques@novasbe.pt               2           5
# 511           annsophie.hahn@novasbe.pt               1           1
# 513           marta.nogueira@novasbe.pt               1           1
# 517              luis.morais@novasbe.pt               2           1
# 519      gambetti.alessandro@novasbe.pt               2           1
# 516         renato.goncalves@novasbe.pt               2           2
# 520             miguel.matos@novasbe.pt               1           2
# 518              paulo.rocha@novasbe.pt               0           3
# 521               joao.costa@novasbe.pt               2           4
# 522             joao.almeida@novasbe.pt               0           1
# 523         renato.goncalves@novasbe.pt               2           1
# 524              luis.morais@novasbe.pt               2           2
# 526      gambetti.alessandro@novasbe.pt               2           3
# 528         claudia.vaqueiro@novasbe.pt               2           3
# 529             miguel.matos@novasbe.pt               1           3
# 527              jose.ferrao@novasbe.pt               0           3
# 525              paulo.rocha@novasbe.pt               0           4
# 531           priya.krishnan@novasbe.pt               2           3
# 530             nuno.ribeiro@novasbe.pt               1           5
# 533         maria.m.carvalho@novasbe.pt               2           1
# 532           natalie.reyher@novasbe.pt               2           4
# 534          tomas.rodrigues@novasbe.pt               2           4
# 535            carlota.lagoa@novasbe.pt               2           1
# 536              rita.mendes@novasbe.pt               2           3
# 537               paulo.ruiz@novasbe.pt               2           1
# 539               iqra.hamid@novasbe.pt               2           1
# 540          tomas.rodrigues@novasbe.pt               2           3
# 538          diogo.a.pereira@novasbe.pt               1           2
# 541            sofia.vilares@novasbe.pt               2           3
# 543             diogo.alvito@novasbe.pt               2           2
# 542           miguel.marques@novasbe.pt               2           3
# 545               radek.oros@novasbe.pt               2           1
# 544        amelia.n.monteiro@novasbe.pt               2           4
# 546      svitlana.sivitskaya@novasbe.pt               1           1
# 547     constanca.b.roquette@novasbe.pt               1           1
# 548           fernanda.rates@novasbe.pt               1           4
# 551             maria.charro@novasbe.pt               2           3
# 550         maria.m.carvalho@novasbe.pt               2           4
# 549      svitlana.sivitskaya@novasbe.pt               1           2
# 552           fernanda.rates@novasbe.pt               1           2
# 554               paulo.ruiz@novasbe.pt               2           2
# 556          guilherme.ramos@novasbe.pt               2           2
# 553             diogo.alvito@novasbe.pt               2           4
# 555           bernardo.costa@novasbe.pt               1           1
# 557              maria.povoa@novasbe.pt               2           2
# 559         claudia.vaqueiro@novasbe.pt               2           4
# 558              ruben.bento@novasbe.pt               1           1
# 560               paulo.ruiz@novasbe.pt               2           3
# 562          guilherme.ramos@novasbe.pt               2           3
# 561           bernardo.costa@novasbe.pt               1           4
# 563         tomas.a.ambrosio@novasbe.pt               2           1
# 565          ayodeji.olufemi@novasbe.pt               2           1
# 567           ines.f.moreira@novasbe.pt               2           1
# 566             abrao.kulaif@novasbe.pt               1           2
# 564         teresa.goncalves@novasbe.pt               1           4
# 568           fernanda.rates@novasbe.pt               1           5
# 574        yulia.vachevskikh@novasbe.pt               2           3
# 572               iqra.hamid@novasbe.pt               2           4
# 573           ines.f.moreira@novasbe.pt               2           5
# 570             miguel.bello@novasbe.pt               1           1
# 569         teresa.goncalves@novasbe.pt               1           3
# 571             abrao.kulaif@novasbe.pt               1           4
# 576        yulia.vachevskikh@novasbe.pt               2           1
# 575  joao.loureiro.rodrigues@novasbe.pt               2           2
# 577           tania.sequeira@novasbe.pt               2           1
# 578             sara.b.lopes@novasbe.pt               2           4
# 579           ana.tapadinhas@novasbe.pt               2           4
# 582    isabel.silva.carvalho@novasbe.pt               2           1
# 580          ayodeji.olufemi@novasbe.pt               2           4
# 581          diogo.guerreiro@novasbe.pt               0           1
# 583             ana.ferreira@novasbe.pt               2           2
# 587           ana.tapadinhas@novasbe.pt               2           2
# 584              maria.povoa@novasbe.pt               2           3
# 585           pedro.m.santos@novasbe.pt               1           1
# 586                joao.gama@novasbe.pt               0           4
# 588        carolina.lourenco@novasbe.pt               2           2
# 590           carlos.marques@novasbe.pt               2           2
# 591           annsophie.hahn@novasbe.pt               1           2
# 589             miguel.bello@novasbe.pt               1           3
# 596           ana.tapadinhas@novasbe.pt               2           1
# 594  joao.loureiro.rodrigues@novasbe.pt               2           3
# 595              maria.povoa@novasbe.pt               2           4
# 597        yulia.vachevskikh@novasbe.pt               2           5
# 592                ana.neves@novasbe.pt               1           1
# 593         teresa.goncalves@novasbe.pt               1           5
# 599          ayodeji.olufemi@novasbe.pt               2           2
# 600    isabel.silva.carvalho@novasbe.pt               2           2
# 598             ana.ferreira@novasbe.pt               2           4
# 601           bernardo.costa@novasbe.pt               1           3
# 602     ana.claudia.oliveira@novasbe.pt               2           4
# 603              andre.nunes@novasbe.pt               2           2
# 604           valter.nobrega@novasbe.pt               2           3
# 605             ana.ferreira@novasbe.pt               2           3
# 606              paulo.rocha@novasbe.pt               0           2
# 607             joao.quelhas@novasbe.pt               0           2
# 608        galina.vysotskaya@novasbe.pt               2           2
# 610             maria.charro@novasbe.pt               2           4
# 609         vitor.cavalcante@novasbe.pt               1           2
# 611       frederica.mendonca@novasbe.pt               1           2
# 614               luis.faria@novasbe.pt               2           1
# 612           natalie.reyher@novasbe.pt               2           3
# 613           marta.nogueira@novasbe.pt               1           3
# 616              ruben.bento@novasbe.pt               1           4
# 615            joao.ferreira@novasbe.pt               0           4
# 618        galina.vysotskaya@novasbe.pt               2           3
# 617             ana.ferreira@novasbe.pt               2           5
# 619         vitor.cavalcante@novasbe.pt               1           4
# 620              afonso.leme@novasbe.pt               2           2
# 623            laman.orujova@novasbe.pt               2           2
# 626                joao.pato@novasbe.pt               2           2
# 621              joana.leite@novasbe.pt               2           3
# 625       frederica.mendonca@novasbe.pt               1           3
# 624                joao.gama@novasbe.pt               0           1
# 622            joao.ferreira@novasbe.pt               0           2
# 627             ana.ferreira@novasbe.pt               2           1
# 629              maria.povoa@novasbe.pt               2           1
# 630                 rita.vaz@novasbe.pt               2           1
# 628              afonso.leme@novasbe.pt               2           5
# 632         patricia.caetano@novasbe.pt               0           1
# 631            joao.ferreira@novasbe.pt               0           3
# 633             joao.almeida@novasbe.pt               0           3
# 635           mariana.coelho@novasbe.pt               2           3
# 634             joao.almeida@novasbe.pt               0           2
# 636          catarina.leitao@novasbe.pt               2           2
# 639             teresa.graca@novasbe.pt               2           1
# 642             maria.charro@novasbe.pt               2           1
# 641             maria.amorim@novasbe.pt               2           2
# 638     ana.claudia.oliveira@novasbe.pt               2           3
# 637             nuno.ribeiro@novasbe.pt               1           1
# 640             abrao.kulaif@novasbe.pt               1           3
# 643              sofia.jesus@novasbe.pt               2           1
# 644           natalie.reyher@novasbe.pt               2           2
# 646    isabel.silva.carvalho@novasbe.pt               2           4
# 645           annsophie.hahn@novasbe.pt               1           3
#
#                                                 course  semester
# 243         2174 || Macroeconomic Analysis || S1 || EN         1
# 245         2174 || Macroeconomic Analysis || S1 || EN         1
# 244         2174 || Macroeconomic Analysis || S1 || EN         1
# 247         2174 || Macroeconomic Analysis || S1 || EN         1
# 248         2174 || Macroeconomic Analysis || S1 || EN         1
# 246         2174 || Macroeconomic Analysis || S1 || EN         1
# 249         2174 || Macroeconomic Analysis || S1 || EN         1
# 251         2174 || Macroeconomic Analysis || S1 || EN         1
# 252         2174 || Macroeconomic Analysis || S1 || EN         1
# 250         2174 || Macroeconomic Analysis || S1 || EN         1
# 253                   2175 || Econometrics || S1 || EN         1
# 254                   2175 || Econometrics || S1 || EN         1
# 255                   2175 || Econometrics || S1 || EN         1
# 256                   2175 || Econometrics || S1 || EN         1
# 258                   2175 || Econometrics || S1 || EN         1
# 257                   2175 || Econometrics || S1 || EN         1
# 259          2176 || Development Economics || S1 || EN         1
# 262          2176 || Development Economics || S1 || EN         1
# 260          2176 || Development Economics || S1 || EN         1
# 263          2176 || Development Economics || S1 || EN         1
# 261          2176 || Development Economics || S1 || EN         1
# 267                    2185 || Game Theory || T2 || EN         0
# 264                    2185 || Game Theory || T2 || EN         0
# 266                    2185 || Game Theory || T2 || EN         0
# 265                    2185 || Game Theory || T2 || EN         0
# 270        2188 || Microeconomic Analysis  || S1 || EN         1
# 271        2188 || Microeconomic Analysis  || S1 || EN         1
# 269        2188 || Microeconomic Analysis  || S1 || EN         1
# 268        2188 || Microeconomic Analysis  || S1 || EN         1
# 278  2193 || Behavioral Economics and Finance || T1...         0
# 277  2193 || Behavioral Economics and Finance || T1...         0
# 275  2193 || Behavioral Economics and Finance || T1...         0
# 274  2193 || Behavioral Economics and Finance || T1...         0
# 279  2193 || Behavioral Economics and Finance || T1...         0
# 272  2193 || Behavioral Economics and Finance || T1...         0
# 273  2193 || Behavioral Economics and Finance || T1...         0
# 276  2193 || Behavioral Economics and Finance || T1...         0
# 284   2194 || History of Economic Analysis || T2 || EN         0
# 282   2194 || History of Economic Analysis || T2 || EN         0
# 281   2194 || History of Economic Analysis || T2 || EN         0
# 280   2194 || History of Economic Analysis || T2 || EN         0
# 283   2194 || History of Economic Analysis || T2 || EN         0
# 285   2194 || History of Economic Analysis || T2 || EN         0
# 288  2204 || Mergers, Acquisitions, Restructuring |...         0
# 289  2204 || Mergers, Acquisitions, Restructuring |...         0
# 287  2204 || Mergers, Acquisitions, Restructuring |...         0
# 286  2204 || Mergers, Acquisitions, Restructuring |...         0
# 290                        2206 || Banking || S1 || EN         1
# 291                        2206 || Banking || S1 || EN         1
# 292                       2215 || Auditing || T2 || EN         0
# 294           2217 || Corporate Governance || T1 || EN         0
# 293           2217 || Corporate Governance || T1 || EN         0
# 296           2217 || Corporate Governance || T2 || EN         0
# 295           2217 || Corporate Governance || T2 || EN         0
# 297                    2218 || Derivatives || T2 || EN         0
# 299   2222 || Financial Statement Analysis || T1 || EN         0
# 300   2222 || Financial Statement Analysis || T1 || EN         0
# 298   2222 || Financial Statement Analysis || T1 || EN         0
# 302                    2229 || Investments || S1 || EN         1
# 303                    2229 || Investments || S1 || EN         1
# 304                    2229 || Investments || S1 || EN         1
# 307                    2229 || Investments || S1 || EN         1
# 308                    2229 || Investments || S1 || EN         1
# 306                    2229 || Investments || S1 || EN         1
# 305                    2229 || Investments || S1 || EN         1
# 301                    2229 || Investments || S1 || EN         1
# 310     2232 || Applied Corporate Finance  || S1 || EN         1
# 311     2232 || Applied Corporate Finance  || S1 || EN         1
# 312     2232 || Applied Corporate Finance  || S1 || EN         1
# 309     2232 || Applied Corporate Finance  || S1 || EN         1
# 313  2233 || Macroeconomics of Financial Markets ||...         0
# 315  2233 || Macroeconomics of Financial Markets ||...         0
# 314  2233 || Macroeconomics of Financial Markets ||...         0
# 318  2233 || Macroeconomics of Financial Markets ||...         0
# 317  2233 || Macroeconomics of Financial Markets ||...         0
# 316  2233 || Macroeconomics of Financial Markets ||...         0
# 320                 2236 || Private Equity || T2 || EN         0
# 321                 2236 || Private Equity || T2 || EN         0
# 319                 2236 || Private Equity || T2 || EN         0
# 322            2238 || Financial Reporting || T1 || EN         0
# 324            2238 || Financial Reporting || T1 || EN         0
# 323            2238 || Financial Reporting || T1 || EN         0
# 327              2253 || Corporate Finance || S1 || EN         1
# 334              2253 || Corporate Finance || S1 || EN         1
# 336              2253 || Corporate Finance || S1 || EN         1
# 337              2253 || Corporate Finance || S1 || EN         1
# 326              2253 || Corporate Finance || S1 || EN         1
# 332              2253 || Corporate Finance || S1 || EN         1
# 335              2253 || Corporate Finance || S1 || EN         1
# 331              2253 || Corporate Finance || S1 || EN         1
# 328              2253 || Corporate Finance || S1 || EN         1
# 330              2253 || Corporate Finance || S1 || EN         1
# 329              2253 || Corporate Finance || S1 || EN         1
# 325              2253 || Corporate Finance || S1 || EN         1
# 333              2253 || Corporate Finance || S1 || EN         1
# 338            2257 || Futures and Options || T2 || EN         0
# 340  2269 || Empirical Methods for Finance || T1 || EN         0
# 341  2269 || Empirical Methods for Finance || T1 || EN         0
# 339  2269 || Empirical Methods for Finance || T1 || EN         0
# 343  2269 || Empirical Methods for Finance || T2 || EN         0
# 344  2269 || Empirical Methods for Finance || T2 || EN         0
# 342  2269 || Empirical Methods for Finance || T2 || EN         0
# 345             2270 || Financial Modeling || T1 || EN         0
# 346             2270 || Financial Modeling || T1 || EN         0
# 347             2270 || Financial Modeling || T1 || EN         0
# 348             2270 || Financial Modeling || T1 || EN         0
# 350             2270 || Financial Modeling || T1 || EN         0
# 349             2270 || Financial Modeling || T1 || EN         0
# 351             2270 || Financial Modeling || T2 || EN         0
# 352             2270 || Financial Modeling || T2 || EN         0
# 353             2270 || Financial Modeling || T2 || EN         0
# 354             2270 || Financial Modeling || T2 || EN         0
# 355             2270 || Financial Modeling || T2 || EN         0
# 356             2277 || Impact Investments || T1 || EN         0
# 358             2277 || Impact Investments || T1 || EN         0
# 359             2277 || Impact Investments || T1 || EN         0
# 357             2277 || Impact Investments || T1 || EN         0
# 362               2327 || Brand Management || S1 || EN         1
# 360               2327 || Brand Management || S1 || EN         1
# 363               2327 || Brand Management || S1 || EN         1
# 364               2327 || Brand Management || S1 || EN         1
# 361               2327 || Brand Management || S1 || EN         1
# 367               2332 || Entrepreneurship || T1 || EN         0
# 368               2332 || Entrepreneurship || T1 || EN         0
# 365               2332 || Entrepreneurship || T1 || EN         0
# 366               2332 || Entrepreneurship || T1 || EN         0
# 370     2336 || Human Resources Management || T1 || EN         0
# 371     2336 || Human Resources Management || T1 || EN         0
# 373     2336 || Human Resources Management || T1 || EN         0
# 372     2336 || Human Resources Management || T1 || EN         0
# 369     2336 || Human Resources Management || T1 || EN         0
# 374     2336 || Human Resources Management || T2 || EN         0
# 375     2336 || Human Resources Management || T2 || EN         0
# 376     2336 || Human Resources Management || T2 || EN         0
# 377     2336 || Human Resources Management || T2 || EN         0
# 378  2337 || Integrated Marketing Communications ||...         0
# 379  2337 || Integrated Marketing Communications ||...         0
# 380  2337 || Integrated Marketing Communications ||...         0
# 382         2338 || International Business || T1 || EN         0
# 384  2339 || International Marketing Strategy || T2...         0
# 383  2339 || International Marketing Strategy || T2...         0
# 385             2352 || Quality Management || T1 || EN         0
# 386             2364 || Venture Simulation || T1 || EN         0
# 388  2375 || Corporate Social Responsibility || T1 ...         0
# 389  2375 || Corporate Social Responsibility || T1 ...         0
# 391  2375 || Corporate Social Responsibility || T1 ...         0
# 393  2375 || Corporate Social Responsibility || T1 ...         0
# 387  2375 || Corporate Social Responsibility || T1 ...         0
# 392  2375 || Corporate Social Responsibility || T1 ...         0
# 390  2375 || Corporate Social Responsibility || T1 ...         0
# 394             2376 || Project Management || T2 || EN         0
# 395             2376 || Project Management || T2 || EN         0
# 396             2376 || Project Management || T2 || EN         0
# 397  2389 || Customer Relationship Management || T1...         0
# 398  2389 || Customer Relationship Management || T1...         0
# 399           2414 || Financial Management || S1 || EN         1
# 400           2414 || Financial Management || S1 || EN         1
# 403           2414 || Financial Management || S1 || EN         1
# 404           2414 || Financial Management || S1 || EN         1
# 405           2414 || Financial Management || S1 || EN         1
# 406           2414 || Financial Management || S1 || EN         1
# 402           2414 || Financial Management || S1 || EN         1
# 401           2414 || Financial Management || S1 || EN         1
# 407                2416 || Family Business || T1 || EN         0
# 409                2416 || Family Business || T1 || EN         0
# 410                2416 || Family Business || T1 || EN         0
# 408                2416 || Family Business || T1 || EN         0
# 412  2417 || Management of Non-Profit Organizations...         0
# 414  2417 || Management of Non-Profit Organizations...         0
# 411  2417 || Management of Non-Profit Organizations...         0
# 413  2417 || Management of Non-Profit Organizations...         0
# 416       2421 || Applied Entrepreneurship || S1 || EN         1
# 418       2421 || Applied Entrepreneurship || S1 || EN         1
# 417       2421 || Applied Entrepreneurship || S1 || EN         1
# 415       2421 || Applied Entrepreneurship || S1 || EN         1
# 420             2430 || Advanced Marketing || S1 || EN         1
# 421             2430 || Advanced Marketing || S1 || EN         1
# 423             2430 || Advanced Marketing || S1 || EN         1
# 422             2430 || Advanced Marketing || S1 || EN         1
# 419             2430 || Advanced Marketing || S1 || EN         1
# 426           2431 || Marketing Management || S1 || EN         1
# 425           2431 || Marketing Management || S1 || EN         1
# 424           2431 || Marketing Management || S1 || EN         1
# 431           2431 || Marketing Management || S1 || EN         1
# 428           2431 || Marketing Management || S1 || EN         1
# 430           2431 || Marketing Management || S1 || EN         1
# 432           2431 || Marketing Management || S1 || EN         1
# 427           2431 || Marketing Management || S1 || EN         1
# 429           2431 || Marketing Management || S1 || EN         1
# 439                  2434 || Statistics II || T1 || EN         0
# 436                  2434 || Statistics II || T1 || EN         0
# 433                  2434 || Statistics II || T1 || EN         0
# 434                  2434 || Statistics II || T1 || EN         0
# 438                  2434 || Statistics II || T1 || EN         0
# 440                  2434 || Statistics II || T1 || EN         0
# 435                  2434 || Statistics II || T1 || EN         0
# 437                  2434 || Statistics II || T1 || EN         0
# 443                  2434 || Statistics II || T2 || EN         0
# 441                  2434 || Statistics II || T2 || EN         0
# 442                  2434 || Statistics II || T2 || EN         0
# 444                  2434 || Statistics II || T2 || EN         0
# 448                 2435 || Statistics III || T1 || EN         0
# 451                 2435 || Statistics III || T1 || EN         0
# 450                 2435 || Statistics III || T1 || EN         0
# 445                 2435 || Statistics III || T1 || EN         0
# 446                 2435 || Statistics III || T1 || EN         0
# 449                 2435 || Statistics III || T1 || EN         0
# 447                 2435 || Statistics III || T1 || EN         0
# 454                 2435 || Statistics III || T2 || EN         0
# 453                 2435 || Statistics III || T2 || EN         0
# 452                 2435 || Statistics III || T2 || EN         0
# 461              2440 || Big Data Analysis || T2 || EN         0
# 457              2440 || Big Data Analysis || T2 || EN         0
# 456              2440 || Big Data Analysis || T2 || EN         0
# 455              2440 || Big Data Analysis || T2 || EN         0
# 460              2440 || Big Data Analysis || T2 || EN         0
# 459              2440 || Big Data Analysis || T2 || EN         0
# 458              2440 || Big Data Analysis || T2 || EN         0
# 462              2441 || Digital Marketing || T2 || EN         0
# 463              2441 || Digital Marketing || T2 || EN         0
# 464      2446 || Small Business Management || T1 || EN         0
# 465      2446 || Small Business Management || T1 || EN         0
# 466      2448 || Business Model Innovation || T2 || EN         0
# 467        2454 || Doing Business in China || T1 || EN         0
# 468              2459 || Advanced Strategy || S1 || EN         1
# 470              2459 || Advanced Strategy || S1 || EN         1
# 469              2459 || Advanced Strategy || S1 || EN         1
# 471            2460 || Strategy Consulting || S1 || EN         1
# 472            2460 || Strategy Consulting || S1 || EN         1
# 473            2460 || Strategy Consulting || S1 || EN         1
# 474  2463 || Advanced Topics in Human Resources Man...         0
# 475  2463 || Advanced Topics in Human Resources Man...         0
# 477  2463 || Advanced Topics in Human Resources Man...         0
# 476  2463 || Advanced Topics in Human Resources Man...         0
# 478            2468 || Technology Strategy || T2 || EN         0
# 479            2468 || Technology Strategy || T2 || EN         0
# 480            2468 || Technology Strategy || T2 || EN         0
# 481            2468 || Technology Strategy || T2 || EN         0
# 482            2468 || Technology Strategy || T2 || EN         0
# 483                    2473 || Negotiation || T1 || EN         0
# 485                    2473 || Negotiation || T1 || EN         0
# 484                    2473 || Negotiation || T1 || EN         0
# 486   2477 || Introduction to Programming  || S1 || EN         1
# 495   2477 || Introduction to Programming  || S1 || EN         1
# 496   2477 || Introduction to Programming  || S1 || EN         1
# 497   2477 || Introduction to Programming  || S1 || EN         1
# 488   2477 || Introduction to Programming  || S1 || EN         1
# 491   2477 || Introduction to Programming  || S1 || EN         1
# 492   2477 || Introduction to Programming  || S1 || EN         1
# 494   2477 || Introduction to Programming  || S1 || EN         1
# 493   2477 || Introduction to Programming  || S1 || EN         1
# 487   2477 || Introduction to Programming  || S1 || EN         1
# 489   2477 || Introduction to Programming  || S1 || EN         1
# 490   2477 || Introduction to Programming  || S1 || EN         1
# 501  2480 || Digital Strategy and Transformation ||...         0
# 498  2480 || Digital Strategy and Transformation ||...         0
# 499  2480 || Digital Strategy and Transformation ||...         0
# 500  2480 || Digital Strategy and Transformation ||...         0
# 502  2481 || Product Design and Development || T1 |...         0
# 503  2481 || Product Design and Development || T1 |...         0
# 505  2481 || Product Design and Development || T1 |...         0
# 504  2481 || Product Design and Development || T1 |...         0
# 506  2483 || Applied Social Entrepreneurship || S1 ...         1
# 508  2483 || Applied Social Entrepreneurship || S1 ...         1
# 509  2483 || Applied Social Entrepreneurship || S1 ...         1
# 507  2483 || Applied Social Entrepreneurship || S1 ...         1
# 515  2484 || Corporate Strategy and Transformation ...         1
# 514  2484 || Corporate Strategy and Transformation ...         1
# 510  2484 || Corporate Strategy and Transformation ...         1
# 512  2484 || Corporate Strategy and Transformation ...         1
# 511  2484 || Corporate Strategy and Transformation ...         1
# 513  2484 || Corporate Strategy and Transformation ...         1
# 517                  2489 || Data Curation || T1 || EN         0
# 519                  2489 || Data Curation || T1 || EN         0
# 516                  2489 || Data Curation || T1 || EN         0
# 520                  2489 || Data Curation || T1 || EN         0
# 518                  2489 || Data Curation || T1 || EN         0
# 521  2490 || Geoeconomics and International Relatio...         0
# 522  2490 || Geoeconomics and International Relatio...         0
# 523             2491 || Data Visualization || T2 || EN         0
# 524             2491 || Data Visualization || T2 || EN         0
# 526             2491 || Data Visualization || T2 || EN         0
# 528             2491 || Data Visualization || T2 || EN         0
# 529             2491 || Data Visualization || T2 || EN         0
# 527             2491 || Data Visualization || T2 || EN         0
# 525             2491 || Data Visualization || T2 || EN         0
# 531            2493 || Marketing Analytics || T2 || EN         0
# 530            2493 || Marketing Analytics || T2 || EN         0
# 533  2496 || Strategic Foresight and Scenario Plann...         0
# 532  2496 || Strategic Foresight and Scenario Plann...         0
# 534  2496 || Strategic Foresight and Scenario Plann...         0
# 535       2500 || Performance and Progress || T2 || EN         0
# 536          2578 || Mastering Your Career || S1 || EN         1
# 537  2581 || Advanced Financial Management || S1 || EN         1
# 539  2581 || Advanced Financial Management || S1 || EN         1
# 540  2581 || Advanced Financial Management || S1 || EN         1
# 538  2581 || Advanced Financial Management || S1 || EN         1
# 541  2582 || Competitive Strategy: An Analytical Ap...         1
# 543                       2584 || Strategy || S1 || EN         1
# 542                       2584 || Strategy || S1 || EN         1
# 545  2585 || Evidence-Based Practices for Wellbeing...         1
# 544  2585 || Evidence-Based Practices for Wellbeing...         1
# 546  2588 || Science-Based Entrepreneurship and Inn...         0
# 547  2588 || Science-Based Entrepreneurship and Inn...         0
# 548  2588 || Science-Based Entrepreneurship and Inn...         0
# 551  2590 || Leading Social Enterprises with Impact...         0
# 550  2590 || Leading Social Enterprises with Impact...         0
# 549  2590 || Leading Social Enterprises with Impact...         0
# 552  2590 || Leading Social Enterprises with Impact...         0
# 554         2597 || Advanced Data Analysis || S1 || EN         1
# 556         2597 || Advanced Data Analysis || S1 || EN         1
# 553         2597 || Advanced Data Analysis || S1 || EN         1
# 555         2597 || Advanced Data Analysis || S1 || EN         1
# 557  2606 || Data Ecosystems and Governance in Orga...         0
# 559                2607 || Digital Markets || T2 || EN         0
# 558                2607 || Digital Markets || T2 || EN         0
# 560  2609 || Data Visualization for Business Analyt...         0
# 562  2609 || Data Visualization for Business Analyt...         0
# 561  2609 || Data Visualization for Business Analyt...         0
# 563                   2613 || Asian Brands || T1 || EN         0
# 565        2626 || Entrepreneurial Journey || S1 || EN         1
# 567        2626 || Entrepreneurial Journey || S1 || EN         1
# 566        2626 || Entrepreneurial Journey || S1 || EN         1
# 564        2626 || Entrepreneurial Journey || S1 || EN         1
# 568        2626 || Entrepreneurial Journey || S1 || EN         1
# 574   2628 || Entrepreneurship with Impact || S1 || EN         1
# 572   2628 || Entrepreneurship with Impact || S1 || EN         1
# 573   2628 || Entrepreneurship with Impact || S1 || EN         1
# 570   2628 || Entrepreneurship with Impact || S1 || EN         1
# 569   2628 || Entrepreneurship with Impact || S1 || EN         1
# 571   2628 || Entrepreneurship with Impact || S1 || EN         1
# 576                  2633 || System Change || T2 || EN         0
# 575                  2633 || System Change || T2 || EN         0
# 577  2641 || Modeling Business Decisions for Operat...         0
# 578         2643 || Social Media Marketing || T1 || EN         0
# 579         2643 || Social Media Marketing || T1 || EN         0
# 582          2648 || Diversity & Inclusion || S1 || EN         1
# 580          2648 || Diversity & Inclusion || S1 || EN         1
# 581          2648 || Diversity & Inclusion || S1 || EN         1
# 583      2649 || Energy and Climate Change || T2 || EN         0
# 587      2649 || Energy and Climate Change || T2 || EN         0
# 584      2649 || Energy and Climate Change || T2 || EN         0
# 585      2649 || Energy and Climate Change || T2 || EN         0
# 586      2649 || Energy and Climate Change || T2 || EN         0
# 588    2650 || Applied Qualitative Studies || T1 || EN         0
# 590  2651 || Digital Transformation in Hospitality ...         0
# 591  2651 || Digital Transformation in Hospitality ...         0
# 589  2651 || Digital Transformation in Hospitality ...         0
# 596  2652 || Fundamentals on Environment and Sustai...         1
# 594  2652 || Fundamentals on Environment and Sustai...         1
# 595  2652 || Fundamentals on Environment and Sustai...         1
# 597  2652 || Fundamentals on Environment and Sustai...         1
# 592  2652 || Fundamentals on Environment and Sustai...         1
# 593  2652 || Fundamentals on Environment and Sustai...         1
# 599                  2656 || Work & Family || T1 || EN         0
# 600                  2656 || Work & Family || T1 || EN         0
# 598                  2656 || Work & Family || T1 || EN         0
# 601  2659 || Data Curation for Business Analytics |...         0
# 602  2688 || Estágio Curricular - Trimestral || T1 ...         0
# 603  2736 || Numerical Methods for Economics and Fi...         0
# 604  2736 || Numerical Methods for Economics and Fi...         0
# 605  2736 || Numerical Methods for Economics and Fi...         0
# 606  2736 || Numerical Methods for Economics and Fi...         0
# 607  2736 || Numerical Methods for Economics and Fi...         0
# 608        2738 || Development Economics I || T2 || EN         0
# 610        2738 || Development Economics I || T2 || EN         0
# 609        2738 || Development Economics I || T2 || EN         0
# 611        2738 || Development Economics I || T2 || EN         0
# 614  2740 || International Relations and Organizati...         0
# 612  2740 || International Relations and Organizati...         0
# 613  2740 || International Relations and Organizati...         0
# 616  2741 || Markets Incentives and Behavior || T1 ...         0
# 615  2741 || Markets Incentives and Behavior || T1 ...         0
# 618               2743 || Policy Appraisal || T2 || EN         0
# 617               2743 || Policy Appraisal || T2 || EN         0
# 619               2743 || Policy Appraisal || T2 || EN         0
# 620                2746 || Public Policy I || T2 || EN         0
# 623                2746 || Public Policy I || T2 || EN         0
# 626                2746 || Public Policy I || T2 || EN         0
# 621                2746 || Public Policy I || T2 || EN         0
# 625                2746 || Public Policy I || T2 || EN         0
# 624                2746 || Public Policy I || T2 || EN         0
# 622                2746 || Public Policy I || T2 || EN         0
# 627   2748 || Statistics for Policy Action || T1 || EN         0
# 629   2748 || Statistics for Policy Action || T1 || EN         0
# 630   2748 || Statistics for Policy Action || T1 || EN         0
# 628   2748 || Statistics for Policy Action || T1 || EN         0
# 632   2748 || Statistics for Policy Action || T1 || EN         0
# 631   2748 || Statistics for Policy Action || T1 || EN         0
# 633   2748 || Statistics for Policy Action || T1 || EN         0
# 635                     2750 || Management || T1 || EN         0
# 634                     2750 || Management || T1 || EN         0
# 636           2827 || Negotiation Strategy || S1 || EN         1
# 639                  2866 || Work Project* || S1 || EN         1
# 642                  2866 || Work Project* || S1 || EN         1
# 641                  2866 || Work Project* || S1 || EN         1
# 638                  2866 || Work Project* || S1 || EN         1
# 637                  2866 || Work Project* || S1 || EN         1
# 640                  2866 || Work Project* || S1 || EN         1
# 643  2951 || Applied Sustainable and Responsible Fi...         1
# 644       2953 || Global Talent Management || T2 || EN         0
# 646       2953 || Global Talent Management || T2 || EN         0
# 645       2953 || Global Talent Management || T2 || EN         0

# %%
# ta_allocations = {}

# for _, row in ms_final_preferences.iterrows():
#     ta = row['TA']
#     course = row['course']
#     ta_capacity = ms_ta_dict[ta]
#     course_weight = ms_courses_dict[course]

#     if course_weight > 0:
#         remaining_weight = course_weight - ta_capacity
#         if ta_capacity > -3 and remaining_weight <= 0:
#             ta_allocations[ta] = course
#             ms_ta_dict[ta] -= course_weight
#             ms_courses_dict[course] = 0
#             ms_final_preferences = ms_final_preferences[ms_final_preferences['course'] != course]
#         elif ta_capacity > -3 and remaining_weight > 0:
#             ta_allocations[ta] = course
#             ms_ta_dict[ta] -= min(course_weight, max(remaining_weight, -3))
#             ms_courses_dict[course] -= min(course_weight, max(remaining_weight, -3))
#     else:
#         ms_final_preferences = ms_final_preferences[ms_final_preferences['course'] != course]
